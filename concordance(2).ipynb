# %% [markdown]
# # Build your own concordance
#
# It took 500 Dominican munks to write the first concordance of the Latin bible, and it took Rabbi Mordecai Nathan 10 years to write the first concordance of the Hebrew bible. With Python, it only takes a matter of seconds to find words in a text, along with the surrounding words.
#
# Run each cell in this notebook one at a time, in order. If something in one cell doesn't work right, it might be because you have overwritten a variable, so try going back and running all the previous cells again.
#
# First run the code and check that everything works. Then, try modifying the code. Start with the first challenges, and then continue in order. Feel free to work together, and see how far you can get. The important thing is to learn, not to solve all the challenges!

# %%
# install the natural language toolkit package (nltk), which has a copy of several texts, 
#including the King James Bible

# %pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the nltk package so that it is accessible to Python, and download a collection of texts from Project Gutenberg
import nltk
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /home/ucloud/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
# Create a variable called "bible" which contains the text of the King James bible.
bible = nltk.corpus.gutenberg.raw('bible-kjv.txt')

# make all characters lowercase
bible = bible.lower()

# remove the "\n" characters, which indicate line breaks in the text (newlines)
bible = bible.replace('\n', ' ')

# split up the text into a long list of individual words
bible = bible.split(' ')

# %%
# make a variable called "concordance", and fill it with every occurrence of the phrase "this world", and a few words preceeding and following "this world"
concordance = []
for i, val in enumerate(bible):
    if val == "world":
        if bible[i-1] == "this":
            concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
# take a look at what the algorithm has found
concordance
# Out:
# ['for the children of this world are in their generation',
#  'them, the children of this world marry, and are given',
#  'hateth his life in this world shall keep it unto',
#  'shall the prince of this world be cast out. ',
#  'should depart out of this world unto the father, having',
#  'for the prince of this world cometh, and hath nothing',
#  'because the prince of this world is judged.  16:12',
#  'of the princes of this world knew: for had they',
#  'for the wisdom of this world is foolishness with god.',
#  'for the fashion of this world passeth away.  7:32',
#  'whom the god of this world hath blinded the minds',
#  'chosen the poor of this world rich in faith, and',
#  'saying, the kingdoms of this world are become the kingdoms']

# %%
# let's see how many instances of the phrase "this world" were found
len(concordance)
# Out:
# 13

# %% [markdown]
# Let's try again, but this time let's just search for "world" by itself, not "this world".

# %%
concordance = []
for i, val in enumerate(bible):
    if val == "world":
        concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
# take a look at what the algorithm has found
concordance
# Out:
# ['and he hath set the world upon them.  2:9',
#  'appeared, the foundations of the world were discovered, at the',
#  'him, all the earth: the world also shall be stable,',
#  'upon the face of the world in the earth. ',
#  'and he shall judge the world in righteousness, he shall',
#  'and the foundations of the world were discovered at thy',
#  'all the ends of the world shall remember and turn',
#  'all the inhabitants of the world stand in awe of',
#  'not tell thee: for the world is mine, and the',
#  'is thine: as for the world and the fulness thereof,',
#  'he hath girded himself: the world also is stablished, that',
#  'that the lord reigneth: the world also shall be established',
#  'earth: he shall judge the world with righteousness, and the',
#  'also he hath set the world in their heart, so',
#  'and i will punish the world for their evil, and',
#  'kingdoms; 14:17 that made the world as a wilderness, and',
#  'fill the face of the world with cities.  14:22',
#  'all the kingdoms of the world upon the face of',
#  'mourneth and fadeth away, the world languisheth and fadeth away,',
#  'earth, the inhabitants of the world will learn righteousness. ',
#  'have the inhabitants of the world fallen.  26:19 thy',
#  'fill the face of the world with fruit.  27:7',
#  'not be ashamed nor confounded world without end.  45:18',
#  'since the beginning of the world men have not heard,',
#  'power, he hath established the world by his wisdom, and',
#  'power, he hath established the world by his wisdom, and',
#  'this world, neither in the world to come.  12:33',
#  ' 18:7 woe unto the world because of offences! for',
#  'be preached in all the world for a witness unto',
#  'since the beginning of the world to this time, no,',
#  'with persecutions; and in the world to come eternal life.',
#  'which have been since the world began: 1:71 that we',
#  'caesar augustus that all the world should be taxed. ',
#  'all the kingdoms of the world in a moment of',
#  'do the nations of the world seek after: and your',
#  'for the children of this world are in their generation',
#  'present time, and in the world to come life everlasting.',
#  'them, the children of this world marry, and are given',
#  'in the world, and the world was made by him,',
#  'made by him, and the world knew him not. ',
#  'not his son into the world to condemn the world;',
#  'the world; but that the world through him might be',
#  'alway ready.  7:7 the world cannot hate you; but',
#  'and i speak to the world those things which i',
#  'heareth.  9:32 since the world began was it not',
#  'ye prevail nothing? behold, the world is gone after him.',
#  'hateth his life in this world shall keep it unto',
#  'shall the prince of this world be cast out. ',
#  'should depart out of this world unto the father, having',
#  'spirit of truth; whom the world cannot receive, because it',
#  'a little while, and the world seeth me no more;',
#  'unto you: not as the world giveth, give i unto',
#  'for the prince of this world cometh, and hath nothing',
#  ' 14:31 but that the world may know that i',
#  'another.  15:18 if the world hate you, ye know',
#  'were of the world, the world would love his own:',
#  'of the world, therefore the world hateth you.  15:20',
#  'come, he will reprove the world of sin, and of',
#  'because the prince of this world is judged.  16:12',
#  'weep and lament, but the world shall rejoice: and ye',
#  'have peace.  in the world ye shall have tribulation:',
#  'had with thee before the world was.  17:6 i',
#  'them thy word; and the world hath hated them, because',
#  'one in us: that the world may believe that thou',
#  'in one; and that the world may know that thou',
#  '17:25 o righteous father, the world hath not known thee:',
#  'i suppose that even the world itself could not contain',
#  'his holy prophets since the world began.  3:22 for',
#  'these that have turned the world upside down are come',
#  '17:24 god that made the world and all things therein,',
#  'which he will judge the world in righteousness by that',
#  'whom all asia and the world worshippeth.  19:28 and',
#  'from the creation of the world are clearly seen, being',
#  'be stopped, and all the world may become guilty before',
#  'was kept secret since the world began, 16:26 but now',
#  'the wisdom of god the world by wisdom knew not',
#  'the foolish things of the world to confound the wise;',
#  'the weak things of the world to confound the things',
#  'which god ordained before the world unto our glory: 2:8',
#  'of the princes of this world knew: for had they',
#  'for the wisdom of this world is foolishness with god.',
#  'the world? and if the world shall be judged by',
#  'for the fashion of this world passeth away.  7:32',
#  'eat no flesh while the world standeth, lest i make',
#  'whom the ends of the world are come.  10:12',
#  'whom the god of this world hath blinded the minds',
#  'was in christ, reconciling the world unto himself, not imputing',
#  'but the sorrow of the world worketh death.  7:11',
#  'jesus christ, by whom the world is crucified unto me,',
#  'from the beginning of the world hath been hid in',
#  'christ jesus throughout all ages, world without end. amen. ',
#  'christ jesus came into the world to save sinners; of',
#  'in christ jesus before the world began, 1:10 but is',
#  'cannot lie, promised before the world began; 1:3 but hath',
#  'not put in subjection the world to come, whereof we',
#  'and the powers of the world to come, 6:6 if',
#  'in the end of the world hath he appeared to',
#  'tormented; 11:38 (of whom the world was not worthy:) they',
#  'chosen the poor of this world rich in faith, and',
#  'tongue is a fire, a world of iniquity: so is',
#  'that the friendship of the world is enmity with god?',
#  'be a friend of the world is the enemy of',
#  'corruption that is in the world through lust.  1:5',
#  'in the flood upon the world of the ungodly; 2:6',
#  'escaped the pollutions of the world through the knowledge of',
#  'the water: 3:6 whereby the world that then was, being',
#  'world.  2:17 and the world passeth away, and the',
#  'sons of god: therefore the world knoweth us not, because',
#  'not, my brethren, if the world hate you.  3:14',
#  'of the world, and the world heareth them.  4:6',
#  'of god, and the whole world lieth in wickedness. ',
#  'saying, the kingdoms of this world are become the kingdoms',
#  'was healed: and all the world wondered after the beast.']

# %%
# let's see how many instances of just the word "world" were found
len(concordance)
# Out:
# 113

# %% [markdown]
# Now, in the cell below, modify the code to search for a different word.

# %%
# add your modified code here and run the cell...
concordance_two = [] 
for i, val in enumerate(bible): # løkke hvor variablen i er indekset (positionen) i listen bible
    # val er ordet ved denne position - løkken gennemgår altså hvert ord i biblen
    
    if val == "upon": #er ordet lig med upon, udføres koden indeni if-blokken
        
        concordance_two.append(str(' '.join(bible[i-5:i+5]))) #sidste del af koden: bible... henter 5 ord før og efter forekomsten af det valgte ord
        # .join samler ordene til en enkelt streng, adskilt af mellemrum
        # .append tilføjer strengen til listen concordance_two

concordance_two
# Out:
# ['and void; and darkness was upon the face of the',
#  'the spirit of god moved upon the face of the',
#  'whose seed is in itself, upon the earth: and it',
#  'the heaven to give light upon the earth: and it',
#  'the heaven to give light upon the earth, 1:18 and',
#  'and every thing that creepeth upon the earth after his',
#  'every creeping thing that creepeth upon the earth.  1:27',
#  'every living thing that moveth upon the earth.  1:29',
#  'herb bearing seed, which is upon the face of all',
#  'to every thing that creepeth upon the earth, wherein there',
#  'not caused it to rain upon the earth, and there',
#  'a deep sleep to fall upon adam, and he slept:',
#  'every beast of the field; upon thy belly shalt thou',
#  'the lord set a mark upon cain, lest any finding',
#  'then began men to call upon the name of the',
#  ' 6:12 and god looked upon the earth, and, behold,',
#  'flesh had corrupted his way upon the earth.  6:13',
#  'bring a flood of waters upon the earth, to destroy',
#  'female; to keep seed alive upon the face of all',
#  'will cause it to rain upon the earth forty days',
#  'the flood of waters was upon the earth.  7:7',
#  'of every thing that creepeth upon the earth, 7:9 there',
#  'waters of the flood were upon the earth.  7:11',
#  '7:12 and the rain was upon the earth forty days',
#  'every creeping thing that creepeth upon the earth after his',
#  'the flood was forty days upon the earth; and the',
#  'prevailed, and were increased greatly upon the earth; and the',
#  'earth; and the ark went upon the face of the',
#  'and the waters prevailed exceedingly upon the earth; and all',
#  'all flesh died that moved upon the earth, both of',
#  'every creeping thing that creepeth upon the earth, and every',
#  'substance was destroyed which was upon the face of the',
#  '7:24 and the waters prevailed upon the earth an hundred',
#  'seventeenth day of the month, upon the mountains of ararat.',
#  'every creeping thing that creepeth upon the earth; that they',
#  'and be fruitful, and multiply upon the earth.  8:18',
#  'every fowl, and whatsoever creepeth upon the earth, after their',
#  'dread of you shall be upon every beast of the',
#  'beast of the earth, and upon every fowl of the',
#  'every fowl of the air, upon all that moveth upon',
#  'air, upon all that moveth upon the earth, and upon',
#  'moveth upon the earth, and upon all the fishes of',
#  'cloud; and i will look upon it, that i may',
#  'of all flesh that is upon the earth.  9:17',
#  'and all flesh that is upon the earth.  9:18',
#  'a garment, and laid it upon both their shoulders, and',
#  'lest we be scattered abroad upon the face of the',
#  'scattered them abroad from thence upon the face of all',
#  'the lord scatter them abroad upon the face of all',
#  'unto the lord, and called upon the name of the',
#  'when the fowls came down upon the carcases, abram drove',
#  'down, a deep sleep fell upon abram; and, lo, an',
#  'horror of great darkness fell upon him.  15:13 and',
#  'unto abram, my wrong be upon thee: i have given',
#  ' 17:17 then abraham fell upon his face, and laughed,',
#  'knead it, and make cakes upon the hearth.  18:7',
#  'that the lord may bring upon abraham that which he',
#  'behold now, i have taken upon me to speak unto',
#  'behold now, i have taken upon me to speak unto',
#  ' 19:3 and he pressed upon them greatly; and they',
#  'them. and they pressed sore upon the man, even lot,',
#  'lingered, the men laid hold upon his hand, and upon',
#  'hold upon his hand, and upon the hand of his',
#  'hand of his wife, and upon the hand of his',
#  '19:23 the sun was risen upon the earth when lot',
#  '19:24 then the lord rained upon sodom and upon gomorrah',
#  'lord rained upon sodom and upon gomorrah brimstone and fire',
#  'cities, and that which grew upon the ground.  19:26',
#  'there for a burnt offering upon one of the mountains',
#  'burnt offering, and laid it upon isaac his son; and',
#  'laid him on the altar upon the wood.  22:10',
#  'said, lay not thine hand upon the lad, neither do',
#  'as the sand which is upon the sea shore; and',
#  "abraham's brother, with her pitcher upon her shoulder.  24:16",
#  'and let down her pitcher upon her hand, and gave',
#  "saw the earring and bracelets upon his sister's hands, and",
#  'and i put the earring upon her face, and the',
#  'her face, and the bracelets upon her hands.  24:48',
#  'her damsels, and they rode upon the camels, and followed',
#  'thou shouldest have brought guiltiness upon us.  26:11 and',
#  'an altar there, and called upon the name of the',
#  'i shall bring a curse upon me, and not a',
#  'his mother said unto him, upon me be thy curse,',
#  'the house, and put them upon jacob her younger son:',
#  'the kids of the goats upon his hands, and upon',
#  'goats upon his hands, and upon the smooth of his',
#  ' 28:11 and he lighted upon a certain place, and',
#  'a pillar, and poured oil upon the top of it.',
#  "and a great stone was upon the well's mouth. ",
#  "and put the stone again upon the well's mouth in",
#  'surely the lord hath looked upon my affliction; now therefore',
#  'her; and she shall bear upon my knees, that i',
#  'behold, the rams which leaped upon the cattle were ringstraked,',
#  'all the rams which leap upon the cattle are ringstraked,',
#  'his sons and his wives upon camels; 31:18 and he',
#  "the camel's furniture, and sat upon them. and laban searched",
#  'the custom of women is upon me. and he searched',
#  'and they did eat there upon the heap.  31:47',
#  '31:54 then jacob offered sacrifice upon the mount, and called',
#  'over penuel the sun rose upon him, and he halted',
#  'upon him, and he halted upon his thigh.  32:32',
#  'sinew which shrank, which is upon the hollow of the',
#  'man his sword, and came upon the city boldly, and',
#  'the sons of jacob came upon the slain, and spoiled',
#  'the terror of god was upon the cities that were',
#  'and jacob set a pillar upon her grave: that is',
#  'wilderness, and lay no hand upon him; that he might',
#  'let not our hand be upon him; for he is',
#  'his clothes, and put sackcloth upon his loins, and mourned',
#  'the midwife took and bound upon his hand a scarlet',
#  'broken forth? this breach be upon thee: therefore his name',
#  'that had the scarlet thread upon his hand: and his',
#  'blessing of the lord was upon all that he had',
#  "master's wife cast her eyes upon joseph; and she said,",
#  'in the morning, and looked upon them, and, behold, they',
#  'them out of the basket upon my head.  40:18',
#  'stood by the other kine upon the brink of the',
#  'ears of corn came up upon one stalk, rank and',
#  'my dream, behold, i stood upon the bank of the',
#  "his hand, and put it upon joseph's hand, and arrayed",
#  'why do ye look one upon another?  42:2 and',
#  'therefore is this distress come upon us.  42:22 and',
#  'occasion against us, and fall upon us, and take us',
#  'for his bowels did yearn upon his brother: and he',
#  'i may set mine eyes upon him.  44:22 and',
#  " 45:14 and he fell upon his brother benjamin's neck,",
#  'and wept; and benjamin wept upon his neck.  45:15',
#  'all his brethren, and wept upon them: and after that',
#  'joseph shall put his hand upon thine eyes.  46:5',
#  "him. and israel bowed himself upon the bed's head. ",
#  'israel strengthened himself, and sat upon the bed.  48:3',
#  "right hand, and laid it upon ephraim's head, who was",
#  "younger, and his left hand upon manasseh's head, guiding his",
#  'father laid his right hand upon the head of ephraim,',
#  'firstborn; put thy right hand upon his head.  48:19',
#  " 50:1 and joseph fell upon his father's face, and",
#  "his father's face, and wept upon him, and kissed him.",
#  "of manasseh were brought up upon joseph's knees.  50:24",
#  'hebrew women, and see them upon the stools; if it',
#  ' 2:25 and god looked upon the children of israel,',
#  'he was afraid to look upon god.  3:7 and',
#  'egypt, ye shall serve god upon this mountain.  3:13',
#  'and ye shall put them upon your sons, and upon',
#  'them upon your sons, and upon your daughters; and ye',
#  'the river, and pour it upon the dry land: and',
#  'the river shall become blood upon the dry land. ',
#  'his sons, and set them upon an ass, and he',
#  'and that he had looked upon their affliction, then they',
#  'our god; lest he fall upon us with pestilence, or',
#  'make heretofore, ye shall lay upon them; ye shall not',
#  'there more work be laid upon the men, that they',
#  'unto them, the lord look upon you, and judge; because',
#  'i may lay my hand upon egypt, and bring forth',
#  'i stretch forth mine hand upon egypt, and bring out',
#  'that is in mine hand upon the waters which are',
#  'and stretch out thine hand upon the waters of egypt,',
#  'upon the waters of egypt, upon their streams, upon their',
#  'of egypt, upon their streams, upon their rivers, and upon',
#  'streams, upon their rivers, and upon their ponds, and upon',
#  'and upon their ponds, and upon all their pools of',
#  'and into thy bedchamber, and upon thy bed, and into',
#  'house of thy servants, and upon thy people, and into',
#  'up both on thee, and upon thy people, and upon',
#  'and upon thy people, and upon all thy servants. ',
#  'cause frogs to come up upon the land of egypt.',
#  'enchantments, and brought up frogs upon the land of egypt.',
#  'and they gathered them together upon heaps: and the land',
#  'not: so there were lice upon man, and upon beast.',
#  'were lice upon man, and upon beast.  8:19 then',
#  'will send swarms of flies upon thee, and upon thy',
#  'of flies upon thee, and upon thy servants, and upon',
#  'and upon thy servants, and upon thy people, and into',
#  'hand of the lord is upon thy cattle which is',
#  'which is in the field, upon the horses, upon the',
#  'the field, upon the horses, upon the asses, upon the',
#  'the horses, upon the asses, upon the camels, upon the',
#  'the asses, upon the camels, upon the oxen, and upon',
#  'camels, upon the oxen, and upon the sheep: there shall',
#  'boil breaking forth with blains upon man, and upon beast,',
#  'with blains upon man, and upon beast, throughout all the',
#  'boil breaking forth with blains upon man, and upon beast.',
#  'with blains upon man, and upon beast.  9:11 and',
#  'boils; for the boil was upon the magicians, and upon',
#  'was upon the magicians, and upon all the egyptians. ',
#  'time send all my plagues upon thine heart, and upon',
#  'plagues upon thine heart, and upon thy servants, and upon',
#  'and upon thy servants, and upon thy people; that thou',
#  'hast in the field; for upon every man and beast',
#  'the hail shall come down upon them, and they shall',
#  'all the land of egypt, upon man, and upon beast,',
#  'of egypt, upon man, and upon beast, and upon every',
#  'man, and upon beast, and upon every herb of the',
#  'and the fire ran along upon the ground; and the',
#  'and the lord rained hail upon the land of egypt.',
#  'the rain was not poured upon the earth.  9:34',
#  'the day that they were upon the earth unto this',
#  'that they may come up upon the land of egypt,',
#  'lord brought an east wind upon the land all that',
#  'i bring one plague more upon pharaoh, and upon egypt;',
#  'plague more upon pharaoh, and upon egypt; afterwards he will',
#  'born of pharaoh that sitteth upon his throne, even unto',
#  'to you for a token upon the houses where ye',
#  'the plague shall not be upon you to destroy you,',
#  'when he seeth the blood upon the lintel, and on',
#  'and the egyptians were urgent upon the people, that they',
#  'bound up in their clothes upon their shoulders.  12:35',
#  'for a sign unto thee upon thine hand, and for',
#  'shall be for a token upon thine hand, and for',
#  'and i will be honoured upon pharaoh, and upon all',
#  'be honoured upon pharaoh, and upon all his host; that',
#  'i will get me honour upon pharaoh, and upon all',
#  'me honour upon pharaoh, and upon all his host, upon',
#  'and upon all his host, upon his chariots, and upon',
#  'host, upon his chariots, and upon his horsemen.  14:18',
#  'i have gotten me honour upon pharaoh, upon his chariots,',
#  'gotten me honour upon pharaoh, upon his chariots, and upon',
#  'pharaoh, upon his chariots, and upon his horsemen.  14:19',
#  'the midst of the sea upon the dry ground: and',
#  'the waters may come again upon the egyptians, upon their',
#  'come again upon the egyptians, upon their chariots, and upon',
#  'egyptians, upon their chariots, and upon their horsemen.  14:27',
#  'the children of israel walked upon dry land in the',
#  'israel saw the egyptians dead upon the sea shore. ',
#  'work which the lord did upon the egyptians: and the',
#  'my lust shall be satisfied upon them; i will draw',
#  'moab, trembling shall take hold upon them; all the inhabitants',
#  'fear and dread shall fall upon them; by the greatness',
#  'the waters of the sea upon them; but the children',
#  'put none of these diseases upon thee, which i have',
#  'thee, which i have brought upon the egyptians: for i',
#  'lay was gone up, behold, upon the face of the',
#  'will stand before thee there upon the rock in horeb;',
#  'the travail that had come upon them by the way,',
#  'sight of all the people upon mount sinai.  19:12',
#  'lightnings, and a thick cloud upon the mount, and the',
#  'smoke, because the lord descended upon it in fire: and',
#  'and the lord came down upon mount sinai, on the',
#  'lest the lord break forth upon them.  19:23 and',
#  'lord, lest he break forth upon them.  19:25 so',
#  'the iniquity of the fathers upon the children unto the',
#  'thy days may be long upon the land which the',
#  'thou lift up thy tool upon it, thou hast polluted',
#  'if a man come presumptuously upon his neighbour, to slay',
#  'rise again, and walk abroad upon his staff, then shall',
#  "the woman's husband will lay upon him; and he shall",
#  'his life whatsoever is laid upon him.  21:31 whether',
#  'if the sun be risen upon him, there shall be',
#  'usurer, neither shalt thou lay upon him usury.  22:26',
#  'his clearness.  24:11 and upon the nobles of the',
#  'glory of the lord abode upon mount sinai, and the',
#  'overlay it, and shalt make upon it a crown of',
#  'put the mercy seat above upon the ark; and in',
#  'the two cherubims which are upon the ark of the',
#  '25:30 and thou shalt set upon the table shewbread before',
#  'shalt make loops of blue upon the edge of the',
#  'hair to be a covering upon the tabernacle: eleven curtains',
#  'and thou shalt hang it upon four pillars of shittim',
#  'hooks shall be of gold, upon the four sockets of',
#  'shalt put the mercy seat upon the ark of the',
#  'make the horns of it upon the four corners thereof:',
#  'of network of brass; and upon the net shalt thou',
#  'and the staves shall be upon the two sides of',
#  'of the ephod, which is upon it, shall be of',
#  'shalt put the two stones upon the shoulders of the',
#  'their names before the lord upon his two shoulders for',
#  '28:22 and thou shalt make upon the breastplate chains at',
#  '28:23 and thou shalt make upon the breastplate two rings',
#  'and thou shalt put them upon the two ends of',
#  'in the breastplate of judgment upon his heart, when he',
#  "thummim; and they shall be upon aaron's heart, when he",
#  'of the children of israel upon his heart before the',
#  'rent.  28:33 and beneath upon the hem of it',
#  'golden bell and a pomegranate, upon the hem of the',
#  '28:35 and it shall be upon aaron to minister: and',
#  'of pure gold, and grave upon it, like the engravings',
#  'lace, that it may be upon the mitre; upon the',
#  'may be upon the mitre; upon the forefront of the',
#  "28:38 and it shall be upon aaron's forehead, that aaron",
#  'and it shall be always upon his forehead, that they',
#  'and thou shalt put them upon aaron thy brother, and',
#  '28:43 and they shall be upon aaron, and upon his',
#  'shall be upon aaron, and upon his sons, when they',
#  'take the garments, and put upon aaron the coat, and',
#  'thou shalt put the mitre upon his head, and put',
#  'and put the holy crown upon the mitre.  29:7',
#  'anointing oil, and pour it upon his head, and anoint',
#  'his sons, and put coats upon them.  29:9 and',
#  'sons shall put their hands upon the head of the',
#  'the bullock, and put it upon the horns of the',
#  'and the fat that is upon them, and burn them',
#  'upon them, and burn them upon the altar.  29:14',
#  'sons shall put their hands upon the head of the',
#  'and sprinkle it round about upon the altar.  29:17',
#  'shalt burn the whole ram upon the altar: it is',
#  'sons shall put their hands upon the head of the',
#  'his blood, and put it upon the tip of the',
#  'right ear of aaron, and upon the tip of the',
#  'ear of his sons, and upon the thumb of their',
#  'of their right hand, and upon the great toe of',
#  'foot, and sprinkle the blood upon the altar round about.',
#  'of the blood that is upon the altar, and of',
#  'anointing oil, and sprinkle it upon aaron, and upon his',
#  'sprinkle it upon aaron, and upon his garments, and upon',
#  'and upon his garments, and upon his sons, and upon',
#  'and upon his sons, and upon the garments of his',
#  'and the fat that is upon them, and the right',
#  'their hands, and burn them upon the altar for a',
#  'that which thou shalt offer upon the altar; two lambs',
#  'by the two corners thereof, upon the two sides of',
#  'lamps, he shall burn incense upon it.  30:8 and',
#  'even, he shall burn incense upon it, a perpetual incense',
#  'aaron shall make an atonement upon the horns of it',
#  'year shall he make atonement upon it throughout your generations:',
#  "throughout your generations.  30:32 upon man's flesh shall it",
#  'whosoever putteth any of it upon a stranger, shall even',
#  'end of communing with him upon mount sinai, two tables',
#  'the writing of god, graven upon the tables.  32:17',
#  'to powder, and strawed it upon the water, and made',
#  'brought so great a sin upon them?  32:22 and',
#  'the lord, even every man upon his son, and upon',
#  'man upon his son, and upon his brother; that he',
#  'brother; that he may bestow upon you a blessing this',
#  'i will visit their sin upon them.  32:35 and',
#  'all the people that are upon the face of the',
#  'me, and thou shalt stand upon a rock: 33:22 and',
#  'first: and i will write upon these tables the words',
#  'the iniquity of the fathers upon the children, and upon',
#  "fathers upon the children, and upon the children's children, unto",
#  'drink water. and he wrote upon the tables the words',
#  'and moses put the vail upon his face again, until',
#  'no fire throughout your habitations upon the sabbath day. ',
#  'and he made fifty loops upon the uttermost edge of',
#  'and fifty loops made he upon the edge of the',
#  'of it; even two rings upon the one side of',
#  'of it, and two rings upon the other side of',
#  'gold, and put the rings upon the four corners that',
#  'made the vessels which were upon the table, his dishes,',
#  'the two corners of it, upon the two sides thereof,',
#  'of his ephod, that was upon it, was of the',
#  ' 39:15 and they made upon the breastplate chains at',
#  'two ends of the breastplate, upon the border of it,',
#  ' 39:24 and they made upon the hems of the',
#  'the bells between the pomegranates upon the hem of the',
#  'of pure gold, and wrote upon it a writing, like',
#  'to fasten it on high upon the mitre; as the',
#  '39:43 and moses did look upon all the work, and,',
#  'to be set in order upon it; and thou shalt',
#  '40:13 and thou shalt put upon aaron the holy garments,',
#  'covering of the tent above upon it; as the lord',
#  'put the mercy seat above upon the ark: 40:21 and',
#  'the tent of the congregation, upon the side of the',
#  'set the bread in order upon it before the lord;',
#  'of the congregation, and offered upon it the burnt offering',
#  'cloud of the lord was upon the tabernacle by day,',
#  'he shall put his hand upon the head of the',
#  'sprinkle the blood round about upon the altar that is',
#  'the priest shall put fire upon the altar, and lay',
#  'lay the wood in order upon the fire: 1:8 and',
#  'and the fat, in order upon the wood that is',
#  'on the fire which is upon the altar: 1:9 but',
#  'sprinkle his blood round about upon the altar.  1:12',
#  'on the fire which is upon the altar: 1:13 but',
#  'it all, and burn it upon the altar: it is',
#  'the priest shall burn it upon the altar, upon the',
#  'burn it upon the altar, upon the wood that is',
#  'upon the wood that is upon the fire: it is',
#  'and he shall pour oil upon it, and put frankincense',
#  'burn the memorial of it upon the altar, to be',
#  'thereof, and shall burn it upon the altar: it is',
#  'and thou shalt put oil upon it, and lay frankincense',
#  'he shall lay his hand upon the head of his',
#  'priests shall sprinkle the blood upon the altar round about.',
#  'all the fat that is upon the inwards, 3:4 and',
#  'burn it on the altar upon the burnt sacrifice, which',
#  'the burnt sacrifice, which is upon the wood that is',
#  'he shall lay his hand upon the head of his',
#  'the blood thereof round about upon the altar.  3:9',
#  'all the fat that is upon the inwards, 3:10 and',
#  'and the fat that is upon them, which is by',
#  'the priest shall burn it upon the altar: it is',
#  'he shall lay his hand upon the head of it,',
#  'shall sprinkle the blood thereof upon the altar round about.',
#  'all the fat that is upon the inwards, 3:15 and',
#  'and the fat that is upon them, which is by',
#  'the priest shall burn them upon the altar: it is',
#  "and shall lay his hand upon the bullock's head, and",
#  'put some of the blood upon the horns of the',
#  'all the fat that is upon the inwards, 4:9 and',
#  'and the fat that is upon them, which is by',
#  'the priest shall burn them upon the altar of the',
#  'congregation shall lay their hands upon the head of the',
#  'put some of the blood upon the horns of the',
#  'from him, and burn it upon the altar.  4:20',
#  'he shall lay his hand upon the head of the',
#  'his finger, and put it upon the horns of the',
#  'shall burn all his fat upon the altar, as the',
#  'he shall lay his hand upon the head of the',
#  'his finger, and put it upon the horns of the',
#  'the priest shall burn it upon the altar for a',
#  'he shall lay his hand upon the head of the',
#  'his finger, and put it upon the horns of the',
#  'the priest shall burn them upon the altar, according to',
#  'blood of the sin offering upon the side of the',
#  'he shall put no oil upon it, neither shall he',
#  'offering, because of the burning upon the altar all night',
#  'linen breeches shall he put upon his flesh, and take',
#  ' 6:12 and the fire upon the altar shall be',
#  'the burnt offering in order upon it; and he shall',
#  'fire shall ever be burning upon the altar; it shall',
#  'all the frankincense which is upon the meat offering, and',
#  'offering, and shall burn it upon the altar for a',
#  'sprinkled of the blood thereof upon any garment, thou shalt',
#  'shall he sprinkle round about upon the altar.  7:3',
#  'the priest shall burn them upon the altar for an',
#  'the lord, having his uncleanness upon him, even that soul',
#  'priest shall burn the fat upon the altar: but the',
#  ' 8:7 and he put upon him the coat, and',
#  'robe, and put the ephod upon him, and he girded',
#  'and he put the breastplate upon him: also he put',
#  'and he put the mitre upon his head; also upon',
#  'mitre upon his head; also upon the mitre, even upon',
#  'also upon the mitre, even upon his forefront, did he',
#  '8:11 and he sprinkled thereof upon the altar seven times,',
#  "poured of the anointing oil upon aaron's head, and anointed",
#  "aaron's sons, and put coats upon them, and girded them",
#  'with girdles, and put bonnets upon them; as the lord',
#  'his sons laid their hands upon the head of the',
#  'the blood, and put it upon the horns of the',
#  'sanctified it, to make reconciliation upon it.  8:16 and',
#  'all the fat that was upon the inwards, and the',
#  'fat, and moses burned it upon the altar.  8:17',
#  'his sons laid their hands upon the head of the',
#  'and moses sprinkled the blood upon the altar round about.',
#  'moses burnt the whole ram upon the altar: it was',
#  'his sons laid their hands upon the head of the',
#  "of it, and put it upon the tip of aaron's",
#  "of aaron's right ear, and upon the thumb of his",
#  'of his right hand, and upon the great toe of',
#  'moses put of the blood upon the tip of their',
#  'of their right ear, and upon the thumbs of their',
#  'of their right hands, and upon the great toes of',
#  'and moses sprinkled the blood upon the altar round about.',
#  'all the fat that was upon the inwards, and the',
#  'them on the fat, and upon the right shoulder: 8:27',
#  "8:27 and he put all upon aaron's hands, and upon",
#  "all upon aaron's hands, and upon his sons' hands, and",
#  'burnt them on the altar upon the burnt offering: they',
#  'of the blood which was upon the altar, and sprinkled',
#  'the altar, and sprinkled it upon aaron, and upon his',
#  'sprinkled it upon aaron, and upon his garments, and upon',
#  'and upon his garments, and upon his sons, and upon',
#  "and upon his sons, and upon his sons' garments with",
#  'the blood, and put it upon the horns of the',
#  'the sin offering, he burnt upon the altar; as the',
#  'which he sprinkled round about upon the altar.  9:13',
#  'head: and he burnt them upon the altar.  9:14',
#  'the legs, and burnt them upon the burnt offering on',
#  'handful thereof, and burnt it upon the altar, beside the',
#  'the blood, which he sprinkled upon the altar round about,',
#  'and they put the fat upon the breasts, and he',
#  'and he burnt the fat upon the altar: 9:21 and',
#  'before the lord, and consumed upon the altar the burnt',
#  'die, and lest wrath come upon all the people: but',
#  'oil of the lord is upon you. and they did',
#  'all fowls that creep, going upon all four, shall be',
#  'flying creeping thing that goeth upon all four, which have',
#  'their feet, to leap withal upon the earth; 11:22 even',
#  ' 11:27 and whatsoever goeth upon his paws, among all',
#  'the creeping things that creep upon the earth; the weasel,',
#  'the even.  11:32 and upon whatsoever any of them,',
#  'part of their carcase fall upon any sowing seed which',
#  'if any water be put upon the seed, and any',
#  'every creeping thing that creepeth upon the earth shall be',
#  'eaten.  11:42 whatsoever goeth upon the belly, and whatsoever',
#  'the belly, and whatsoever goeth upon all four, or whatsoever',
#  'all creeping things that creep upon the earth, them ye',
#  'of creeping thing that creepeth upon the earth.  11:45',
#  'of every creature that creepeth upon the earth: 11:47 to',
#  'then the priest shall look upon it: and, behold, if',
#  'and the priest shall look upon him the seventh day:',
#  'or woman have a plague upon the head or the',
#  'dry scall, even a leprosy upon the head or beard.',
#  'then the priest shall look upon it: and, behold, if',
#  'he shall put a covering upon his upper lip, and',
#  'and the priest shall look upon the plague, and shut',
#  '14:7 and he shall sprinkle upon him that is to',
#  'the priest shall put it upon the tip of the',
#  'is to be cleansed, and upon the thumb of his',
#  'of his right hand, and upon the great toe of',
#  'hand shall the priest put upon the tip of the',
#  'is to be cleansed, and upon the thumb of his',
#  'of his right hand, and upon the great toe of',
#  'toe of his right foot, upon the blood of the',
#  "priest's hand he shall pour upon the head of him",
#  'offering and the meat offering upon the altar: and the',
#  'trespass offering, and put it upon the tip of the',
#  'is to be cleansed, and upon the thumb of his',
#  'of his right hand, and upon the great toe of',
#  'that is in his hand upon the tip of the',
#  'is to be cleansed, and upon the thumb of his',
#  'of his right hand, and upon the great toe of',
#  'toe of his right foot, upon the place of the',
#  "priest's hand he shall put upon the head of him",
#  'shall come in, and look upon it, and, behold, the',
#  'that hath the issue spit upon him that is clean;',
#  'what saddle soever he rideth upon that hath the issue',
#  'every thing that she lieth upon in her separation shall',
#  'thing also that she sitteth upon shall be unclean. ',
#  'any thing that she sat upon shall wash his clothes,',
#  'all, and her flowers be upon him, he shall be',
#  'separation: and whatsoever she sitteth upon shall be unclean, as',
#  'the mercy seat, which is upon the ark; that he',
#  'will appear in the cloud upon the mercy seat. ',
#  'shall have the linen breeches upon his flesh, and shall',
#  'and aaron shall cast lots upon the two goats; one',
#  "aaron shall bring the goat upon which the lord's lot",
#  'he shall put the incense upon the fire before the',
#  'the mercy seat that is upon the testimony, that he',
#  'sprinkle it with his finger upon the mercy seat eastward;',
#  'the bullock, and sprinkle it upon the mercy seat, and',
#  'the goat, and put it upon the horns of the',
#  'shall sprinkle of the blood upon it with his finger',
#  'shall lay both his hands upon the head of the',
#  'all their sins, putting them upon the head of the',
#  'and the goat shall bear upon him all their iniquities',
#  'sin offering shall he burn upon the altar.  16:26',
#  'priest shall sprinkle the blood upon the altar of the',
#  'have given it to you upon the altar to make',
#  'do visit the iniquity thereof upon it, and the land',
#  'neighbour, and not suffer sin upon him.  19:18 thou',
#  'of linen and woollen come upon thee.  19:20 and',
#  'dead, nor print any marks upon you: i am the',
#  'mother; his blood shall be upon him.  20:10 and',
#  'death; their blood shall be upon them.  20:12 and',
#  'confusion; their blood shall be upon them.  20:13 if',
#  'death; their blood shall be upon them.  20:14 and',
#  'death; their blood shall be upon them.  20:17 and',
#  'stones: their blood shall be upon them.  21:1 and',
#  'they shall not make baldness upon their head, neither shall',
#  'high priest among his brethren, upon whose head the anointing',
#  'oil of his god is upon him: i am the',
#  'the lord, having his uncleanness upon him, that soul shall',
#  'offering by fire of them upon the altar unto the',
#  'and drink offerings, every thing upon his day: 23:38 beside',
#  'he shall order the lamps upon the pure candlestick before',
#  'rows, six on a row, upon the pure table before',
#  'thou shalt put pure frankincense upon each row, that it',
#  'heard him lay their hands upon his head, and let',
#  'i will command my blessing upon you in the sixth',
#  'not give him thy money upon usury, nor lend him',
#  'bring seven times more plagues upon you according to your',
#  'i will bring a sword upon you, that shall avenge',
#  'images, and cast your carcases upon the carcases of your',
#  'your sabbaths, when ye dwelt upon it.  26:36 and',
#  'upon it.  26:36 and upon them that are left',
#  'and they shall fall one upon another, as it were',
#  'that there be no wrath upon the congregation of the',
#  'staves thereof.  4:7 and upon the table of shewbread',
#  '4:8 and they shall spread upon them a cloth of',
#  'skins, and shall put it upon a bar.  4:11',
#  'a bar.  4:11 and upon the golden altar they',
#  '4:14 and they shall put upon it all the vessels',
#  'altar; and they shall spread upon it a covering of',
#  "badgers' skins that is above upon it, and the hanging",
#  'the spirit of jealousy come upon him, and he be',
#  'the spirit of jealousy come upon him, and he be',
#  'he shall pour no oil upon it, nor put frankincense',
#  'the lord, and offer it upon the altar: 5:26 and',
#  'memorial thereof, and burn it upon the altar, and afterward',
#  'the spirit of jealousy cometh upon him, and he be',
#  'and the priest shall execute upon her all this law.',
#  'there shall no razor come upon his head: until the',
#  'consecration of his god is upon his head.  6:8',
#  'wafer, and shall put them upon the hands of the',
#  'lord make his face shine upon thee, and be gracious',
#  'lord lift up his countenance upon thee, and give thee',
#  'they shall put my name upon the children of israel,',
#  'was that they should bear upon their shoulders.  7:10',
#  'the mercy seat that was upon the ark of testimony,',
#  'them: sprinkle water of purifying upon them, and let them',
#  'israel shall put their hands upon the levites: 8:11 and',
#  'levites shall lay their hands upon the heads of the',
#  'shall go in to wait upon the service of the',
#  'years they shall cease waiting upon the service thereof, and',
#  'and at even there was upon the tabernacle as it',
#  'long as the cloud abode upon the tabernacle they rested',
#  'when the cloud tarried long upon the tabernacle many days,',
#  'cloud was a few days upon the tabernacle; according to',
#  'year, that the cloud tarried upon the tabernacle, remaining thereon,',
#  'cloud of the lord was upon them by day, when',
#  'and when the dew fell upon the camp in the',
#  'the night, the manna fell upon it.  11:10 then',
#  'burden of all this people upon me?  11:12 have',
#  'of the spirit which is upon thee, and will put',
#  'thee, and will put it upon them; and they shall',
#  'of the spirit that was upon him, and gave it',
#  'that, when the spirit rested upon them, they prophesied, and',
#  'medad: and the spirit rested upon them; and they were',
#  'lord would put his spirit upon them!  11:30 and',
#  'it were two cubits high upon the face of the',
#  'all the men which were upon the face of the',
#  'as snow: and aaron looked upon miriam, and, behold, she',
#  'thee, lay not the sin upon us, wherein we have',
#  'they bare it between two upon a staff; and they',
#  'the iniquity of the fathers upon the children unto the',
#  'by bringing up a slander upon the land, 14:37 even',
#  'bring up the evil report upon the land, died by',
#  'off; his iniquity shall be upon him.  15:32 and',
#  'a man that gathered sticks upon the sabbath day. ',
#  'generations, and that they put upon the fringe of the',
#  'fringe, that ye may look upon it, and remember all',
#  'them, ye take too much upon you, seeing all the',
#  'moses heard it, he fell upon his face: 16:5 and',
#  'holy: ye take too much upon you, ye sons of',
#  ' 16:22 and they fell upon their faces, and said,',
#  'pit, and the earth closed upon them: and they perished',
#  'a moment. and they fell upon their faces.  16:46',
#  "write thou every man's name upon his rod.  17:3",
#  "thou shalt write aaron's name upon the rod of levi:",
#  'be no wrath any more upon the children of israel.',
#  'thou shalt sprinkle their blood upon the altar, and shalt',
#  'wherein is no blemish, and upon which never came yoke:',
#  'of separation was not sprinkled upon him, he shall be',
#  'unclean; his uncleanness is yet upon him.  19:14 this',
#  'which hath no covering bound upon it, is unclean. ',
#  'the water, and sprinkle it upon the tent, and upon',
#  'it upon the tent, and upon all the vessels, and',
#  'upon all the vessels, and upon the persons that were',
#  'persons that were there, and upon him that touched a',
#  'the clean person shall sprinkle upon the unclean on the',
#  'separation hath not been sprinkled upon him; he is unclean.',
#  'the congregation, and they fell upon their faces: and the',
#  'his garments, and put them upon eleazar his son: and',
#  'his garments, and put them upon eleazar his son; and',
#  'fiery serpent, and set it upon a pole: and it',
#  'is bitten, when he looketh upon it, shall live. ',
#  'of brass, and put it upon a pole, and it',
#  'dwelling of ar, and lieth upon the border of moab.',
#  'him. now he was riding upon his ass, and his',
#  'am not i thine ass, upon which thou hast ridden',
#  'altars, and i have offered upon every altar a bullock',
#  'the spirit of god came upon him.  24:3 and',
#  'spirit, and lay thine hand upon him; 27:19 and set',
#  'put some of thine honour upon him, that all the',
#  'and he laid his hands upon him, and gave him',
#  'all her bonds, which are upon her: he confirmeth them,',
#  'them that took the war upon them, who went out',
#  'lord had smitten among them: upon their gods also the',
#  'without enmity, or have cast upon him any thing without',
#  'him not, and cast it upon him, that he die,',
#  'and the fear of thee upon the nations that are',
#  'all things that we call upon him for?  4:8',
#  'days that they shall live upon the earth, and that',
#  'commandments; and he wrote them upon two tables of stone.',
#  'shall not prolong your days upon it, but shall utterly',
#  'all these things are come upon thee, even in the',
#  'day that god created man upon the earth, and ask',
#  'he might instruct thee: and upon earth he shewed thee',
#  'god in heaven above, and upon the earth beneath: there',
#  'thou mayest prolong thy days upon the earth, which the',
#  'the iniquity of the fathers upon the children unto the',
#  'bind them for a sign upon thine hand, and they',
#  'and thou shalt write them upon the posts of thy',
#  'and wonders, great and sore, upon egypt, upon pharaoh, and',
#  'great and sore, upon egypt, upon pharaoh, and upon all',
#  'upon egypt, upon pharaoh, and upon all his household, before',
#  'above all people that are upon the face of the',
#  'did not set his love upon you, nor choose you,',
#  'of egypt, which thou knowest, upon thee; but will lay',
#  'thee; but will lay them upon all them that hate',
#  'eye shall have no pity upon them: neither shalt thou',
#  'beasts of the field increase upon thee.  7:23 but',
#  'thy raiment waxed not old upon thee, neither did thy',
#  'lord thy god are always upon it, from the beginning',
#  'bind them for a sign upon your hand, that they',
#  'and thou shalt write them upon the door posts of',
#  'posts of thine house, and upon thy gates: 11:21 that',
#  'as the days of heaven upon the earth.  11:22',
#  'and the dread of you upon all the land that',
#  'thou shalt put the blessing upon mount gerizim, and the',
#  'mount gerizim, and the curse upon mount ebal.  11:30',
#  'the days that ye live upon the earth.  12:2',
#  'shall possess served their gods, upon the high mountains, and',
#  'upon the high mountains, and upon the hills, and under',
#  'blood; ye shall pour it upon the earth as water.',
#  'as long as thou livest upon the earth.  12:20',
#  'it; thou shalt pour it upon the earth as water.',
#  'the flesh and the blood, upon the altar of the',
#  'sacrifices shall be poured out upon the altar of the',
#  'thine hand shall be first upon him to put him',
#  'thee mercy, and have compassion upon thee, and multiply thee,',
#  'all the nations that are upon the earth.  14:3',
#  'thereof; thou shalt pour it upon the ground as water.',
#  'the witnesses shall be first upon him to put him',
#  'shall be, when he sitteth upon the throne of his',
#  'from the helve, and lighteth upon his neighbour, that he',
#  'inheritance, and so blood be upon thee.  19:11 but',
#  'shall not remain all night upon the tree, but thou',
#  'eggs, and the dam sitting upon the young, or upon',
#  'sitting upon the young, or upon the eggs, thou shalt',
#  'that thou bring not blood upon thine house, if any',
#  'thou shalt make thee fringes upon the four quarters of',
#  'bring up an evil name upon her, and say, i',
#  'brought up an evil name upon a virgin of israel:',
#  'thou shalt have a paddle upon thy weapon; and it',
#  '23:19 thou shalt not lend upon usury to thy brother;',
#  'any thing that is lent upon usury: 23:20 unto a',
#  'a stranger thou mayest lend upon usury; but unto thy',
#  'brother thou shalt not lend upon usury: that the lord',
#  'shall the sun go down upon it; for he is',
#  'poor, and setteth his heart upon it: lest he cry',
#  'and afflicted us, and laid upon us hard bondage: 26:7',
#  '27:3 and thou shalt write upon them all the words',
#  'lift up any iron tool upon them.  27:6 thou',
#  '27:8 and thou shalt write upon the stones all the',
#  'saying, 27:12 these shall stand upon mount gerizim to bless',
#  '27:13 and these shall stand upon mount ebal to curse;',
#  'lord shall command the blessing upon thee in thy storehouses,',
#  'all these curses shall come upon thee, and overtake thee:',
#  '28:20 the lord shall send upon thee cursing, vexation, and',
#  'heaven shall it come down upon thee, until thou be',
#  'all these curses shall come upon thee, and shall pursue',
#  '28:46 and they shall be upon thee for a sign',
#  'and for a wonder, and upon thy seed for ever.',
#  'put a yoke of iron upon thy neck, until he',
#  'the sole of her foot upon the ground for delicateness',
#  '28:60 moreover he will bring upon thee all the diseases',
#  'them will the lord bring upon thee, until thou be',
#  'clothes are not waxen old upon you, and thy shoe',
#  'shoe is not waxen old upon thy foot.  29:6',
#  'in this book shall lie upon him, and the lord',
#  'which the lord hath laid upon it; 29:23 and that',
#  'against this land, to bring upon it all the curses',
#  'all these things are come upon thee, the blessing and',
#  'thy captivity, and have compassion upon thee, and will return',
#  'will put all these curses upon thine enemies, and on',
#  'shall not prolong your days upon the land, whither thou',
#  'are not these evils come upon us, because our god',
#  'dew, as the small rain upon the tender herb, and',
#  'herb, and as the showers upon the grass: 32:3 because',
#  '32:23 i will heap mischiefs upon them; i will spend',
#  'i will spend mine arrows upon them.  32:24 they',
#  'send the teeth of beasts upon them, with the poison',
#  'the things that shall come upon them make haste. ',
#  'from the beginning of revenges upon the enemy.  32:43',
#  'thee, and whole burnt sacrifice upon thine altar.  33:11',
#  'bush: let the blessing come upon the head of joseph,',
#  'the head of joseph, and upon the top of the',
#  'god of jeshurun, who rideth upon the heaven in thy',
#  'fountain of jacob shall be upon a land of corn',
#  'thee; and thou shalt tread upon their high places. ',
#  'moses had laid his hands upon him: and the children',
#  'she had laid in order upon the roof.  2:7',
#  'she came up unto them upon the roof; 2:9 and',
#  'that your terror is fallen upon us, and that all',
#  'window: for her house was upon the town wall, and',
#  'town wall, and she dwelt upon the wall.  2:16',
#  'street, his blood shall be upon his head, and we',
#  'head, if any hand be upon him.  2:20 and',
#  'above; and they shall stand upon an heap.  3:14',
#  'above stood and rose up upon an heap very far',
#  'man of you a stone upon his shoulder, according unto',
#  'and fell to the earth upon his face before the',
#  'of israel, and put dust upon their heads.  7:7',
#  'up; wherefore liest thou thus upon thy face?  7:11',
#  'from the ambush, and seize upon the city: for the',
#  'to the wilderness turned back upon the pursuers.  8:21',
#  '8:32 and he wrote there upon the stones a copy',
#  'ambassadors, and took old sacks upon their asses, and wine',
#  'and old shoes and clouted upon their feet, and old',
#  'their feet, and old garments upon them; and all the',
#  'them live, lest wrath be upon us, because of the',
#  'down great stones from heaven upon them unto azekah, and',
#  'israel, sun, stand thou still upon gibeon; and thou, moon,',
#  'the people had avenged themselves upon their enemies. is not',
#  'joshua said, roll great stones upon the mouth of the',
#  'come near, put your feet upon the necks of these',
#  'near, and put their feet upon the necks of them.',
#  'trees: and they were hanging upon the trees until the',
#  'as the sand that is upon the sea shore in',
#  'merom suddenly; and they fell upon them.  11:8 and',
#  'ruled from aroer, which is upon the bank of the',
#  '13:9 from aroer, that is upon the bank of the',
#  'west side, and to judah upon jordan toward the sunrising.',
#  'assigned bezer in the wilderness upon the plain out of',
#  'all good things are come upon you, which the lord',
#  'so shall the lord bring upon you all evil things,',
#  'egyptians, and brought the sea upon them, and covered them;',
#  'spirit of the lord came upon him, and he judged',
#  'gird it under his raiment upon his right thigh. ',
#  'blade; and the fat closed upon the blade, so that',
#  'the doors of the parlour upon him, and locked them.',
#  'the host of sisera fell upon the edge of the',
#  '6:14 and the lord looked upon him, and said, go',
#  'unleavened cakes, and lay them upon this rock, and pour',
#  'unto the lord thy god upon the top of this',
#  'the second bullock was offered upon the altar that was',
#  'spirit of the lord came upon gideon, and he blew',
#  'only, and it be dry upon all the earth beside,',
#  'it now be dry only upon the fleece, and upon',
#  'only upon the fleece, and upon all the ground let',
#  'night: for it was dry upon the fleece only, and',
#  'every one that boweth down upon his knees to drink.',
#  'of the people bowed down upon their knees to drink',
#  'zeeb; and they slew oreb upon the rock oreb, and',
#  'said, rise thou, and fall upon us: for as the',
#  'being threescore and ten persons, upon one stone: notwithstanding yet',
#  'sons, threescore and ten persons, upon one stone, and have',
#  'and their blood be laid upon abimelech their brother, which',
#  'brother, which slew them; and upon the men of shechem,',
#  'shalt rise early, and set upon the city: and, behold,',
#  'the two other companies ran upon all the people that',
#  'set the hold on fire upon them; so that all',
#  "a piece of a millstone upon abimelech's head, and all",
#  'of shechem did god render upon their heads: and upon',
#  'render upon their heads: and upon them came the curse',
#  'spirit of the lord came upon jephthah, and he passed',
#  'may go up and down upon the mountains, and bewail',
#  'companions, and bewailed her virginity upon the mountains.  11:39',
#  'we will burn thine house upon thee with fire. ',
#  'meat offering, and offered it upon a rock unto the',
#  'of the lord came mightily upon him, and he rent',
#  'her, because she lay sore upon him: and she told',
#  'spirit of the lord came upon him, and he went',
#  'that ye will not fall upon me yourselves.  15:13',
#  'of the lord came mightily upon him, and the cords',
#  'and the cords that were upon his arms became as',
#  'jawbone of an ass, heaps upon heaps, with the jaw',
#  'and all, and put them upon his shoulders, and carried',
#  'unto him, the philistines be upon thee, samson. and he',
#  'unto him, the philistines be upon thee, samson. and there',
#  'unto him, the philistines be upon thee, samson. and he',
#  'hath not come a razor upon mine head; for i',
#  'and she made him sleep upon her knees; and she',
#  'she said, the philistines be upon thee, samson. and he',
#  'standeth, that i may lean upon them.  16:27 now',
#  'were there; and there were upon the roof about three',
#  'of the two middle pillars upon which the house stood,',
#  'might; and the house fell upon the lords, and upon',
#  'fell upon the lords, and upon all the people that',
#  'thy peace, lay thine hand upon thy mouth, and go',
#  'us, lest angry fellows run upon thee, and thou lose',
#  'and the sun went down upon them when they were',
#  'let all thy wants lie upon me; only lodge not',
#  'house, and her hands were upon the threshold.  19:28',
#  'the man took her up upon an ass, and the',
#  'beset the house round about upon me by night, and',
#  'in wait hasted, and rushed upon gibeah; and the liers',
#  'saw that evil was come upon them.  20:42 therefore',
#  'men of israel turned again upon the children of benjamin,',
#  'thee, and put thy raiment upon thee, and get thee',
#  'the vail that thou hast upon thee, and hold it.',
#  'the name of the dead upon his inheritance.  4:6',
#  'the name of the dead upon his inheritance, that the',
#  'now eli the priest sat upon a seat by a',
#  'there shall no razor come upon his head.  1:12',
#  'he hath set the world upon them.  2:9 he',
#  'of heaven shall he thunder upon them: the lord shall',
#  'be my priest, to offer upon mine altar, to burn',
#  'unto thee, that shall come upon thy two sons, on',
#  'clothes rent, and with earth upon his head.  4:13',
#  'he came, lo, eli sat upon a seat by the',
#  'travailed; for her pains came upon her.  4:20 and',
#  'morrow, behold, dagon was fallen upon his face to the',
#  'morning, behold, dagon was fallen upon his face to the',
#  'his hands were cut off upon the threshold; only the',
#  'of the lord was heavy upon them of ashdod, and',
#  'for his hand is sore upon us, and upon dagon',
#  'is sore upon us, and upon dagon our god. ',
#  'the lord, and lay it upon the cart; and put',
#  'the ark of the lord upon the cart, and the',
#  'great thunder on that day upon the philistines, and discomfited',
#  'philistines: for i have looked upon my people, because their',
#  'shoulder, and that which was upon it, and set it',
#  'city, samuel communed with saul upon the top of the',
#  'of oil, and poured it upon his head, and kissed',
#  'of the lord will come upon thee, and thou shalt',
#  'the spirit of god came upon him, and he prophesied',
#  'lay it for a reproach upon all israel.  11:3',
#  'the spirit of god came upon saul when he heard',
#  'philistines will come down now upon me to gilgal, and',
#  'lord have established thy kingdom upon israel for ever. ',
#  'now it came to pass upon a day, that jonathan',
#  '14:13 and jonathan climbed up upon his hands and upon',
#  'up upon his hands and upon his feet, and his',
#  'wood; and there was honey upon the ground.  14:26',
#  '14:32 and the people flew upon the spoil, and took',
#  'the lord, but didst fly upon the spoil, and didst',
#  'go away, he laid hold upon the skirt of his',
#  'spirit of the lord came upon david from that day',
#  'evil spirit from god is upon thee, that he shall',
#  'evil spirit from god was upon saul, that david took',
#  'had an helmet of brass upon his head, and he',
#  'he had greaves of brass upon his legs, and a',
#  'put an helmet of brass upon his head; also he',
#  'and david girded his sword upon his armour, and he',
#  'his forehead; and he fell upon his face to the',
#  'therefore david ran, and stood upon the philistine, and took',
#  'of the robe that was upon him, and gave it',
#  'evil spirit from god came upon saul, and he prophesied',
#  'let not mine hand be upon him, but let the',
#  'hand of the philistines be upon him.  18:18 and',
#  'spirit from the lord was upon saul, as he sat',
#  'the spirit of god was upon the messengers of saul,',
#  'the spirit of god was upon him also, and he',
#  'by my father to come upon thee, then would not',
#  '20:25 and the king sat upon his seat, as at',
#  'as at other times, even upon a seat by the',
#  'the son of jesse liveth upon the ground, thou shalt',
#  'let his spittle fall down upon his beard.  21:14',
#  'forth their hand to fall upon the priests of the',
#  'doeg, turn thou, and fall upon the priests. and doeg',
#  'edomite turned, and he fell upon the priests, and slew',
#  'seek david and his men upon the rocks of the',
#  'mine hand shall not be upon thee.  24:13 as',
#  'mine hand shall not be upon thee.  24:14 after',
#  'at his feet, and said, upon me, my lord, upon',
#  'said, upon me, my lord, upon me let this iniquity',
#  'returned the wickedness of nabal upon his own head. and',
#  'hasted, and arose and rode upon an ass, with five',
#  'from the lord was fallen upon them.  26:13 then',
#  'nor executedst his fierce wrath upon amalek, therefore hath the',
#  'from the earth, and sat upon the bed.  28:24',
#  '30:14 we made an invasion upon the south of the',
#  'south of the cherethites, and upon the coast which belongeth',
#  'which belongeth to judah, and upon the south of caleb;',
#  'behold, they were spread abroad upon all the earth, eating',
#  'hundred young men, which rode upon camels, and fled. ',
#  'and the philistines followed hard upon saul and upon his',
#  'followed hard upon saul and upon his sons; and the',
#  'took a sword, and fell upon it.  31:5 and',
#  'was dead, he fell likewise upon his sword, and died',
#  'his clothes rent, and earth upon his head: and so',
#  'as i happened by chance upon mount gilboa, behold, saul',
#  'mount gilboa, behold, saul leaned upon his spear; and, lo,',
#  'again, stand, i pray thee, upon me, and slay me:',
#  'me: for anguish is come upon me, because my life',
#  ' 1:10 so i stood upon him, and slew him,',
#  'took the crown that was upon his head, and the',
#  'said, go near, and fall upon him. and he smote',
#  'unto him, thy blood be upon thy head; for thy',
#  'beauty of israel is slain upon thy high places: how',
#  'neither let there be rain, upon you, nor fields of',
#  'put on ornaments of gold upon your apparel.  1:25',
#  'person in his own house upon his bed? shall i',
#  'the lord hath broken forth upon mine enemies before me,',
#  'compass behind them, and come upon them over against the',
#  'set the ark of god upon a new cart, and',
#  'lord had made a breach upon uzzah: and he called',
#  'servant, that thou shouldest look upon such a dead dog',
#  'off his bed, and walked upon the roof of the',
#  'a piece of a millstone upon him from the wall,',
#  'the field, and we were upon them even unto the',
#  'shot from off the wall upon thy servants; and some',
#  'in, and lay all night upon the earth.  12:17',
#  'a garment of divers colours upon her: for with such',
#  'every man gat him up upon his mule, and fled.',
#  'husband neither name nor remainder upon the earth.  14:8',
#  'us suddenly, and bring evil upon us, and smite the',
#  'his coat rent, and earth upon his head: 15:33 unto',
#  'couple of asses saddled, and upon them two hundred loaves',
#  '16:8 the lord hath returned upon thee all the blood',
#  'they spread absalom a tent upon the top of the',
#  '17:2 and i will come upon him while he is',
#  '17:12 so shall we come upon him in some place',
#  'found, and we will light upon him as the dew',
#  'the lord might bring evil upon absalom.  17:15 then',
#  'of david. and absalom rode upon a mule, and the',
#  'very great heap of stones upon him: and all israel',
#  'fell down to the earth upon his face before the',
#  'was girded unto him, and upon it a girdle with',
#  'girdle with a sword fastened upon his loins in the',
#  'field, and cast a cloth upon him, when he saw',
#  'and spread it for her upon the rock, from the',
#  'of harvest until water dropped upon them out of heaven,',
#  'in my distress i called upon the lord, and cried',
#  ' 22:11 and he rode upon a cherub, and did',
#  'fly: and he was seen upon the wings of the',
#  'save: but thine eyes are upon the haughty, that thou',
#  "hinds' feet: and setteth me upon my high places. ",
#  'the lord sent a pestilence upon israel from the morning',
#  'angel stretched out his hand upon jerusalem to destroy it,',
#  'the king on his face upon the ground.  24:21',
#  'me, and he shall sit upon my throne? why then',
#  'me, and he shall sit upon my throne.  1:18',
#  'eyes of all israel are upon thee, that thou shouldest',
#  'me, and he shall sit upon my throne?  1:25',
#  'me, and he shall sit upon my throne in my',
#  'solomon my son to ride upon mine own mule, and',
#  'he may come and sit upon my throne; for he',
#  "and caused solomon to ride upon king david's mule, and",
#  "have caused him to ride upon the king's mule: 1:45",
#  'and the king bowed himself upon the bed.  1:48',
#  'put the blood of war upon his girdle that was',
#  ' 2:12 then sat solomon upon the throne of david',
#  'of jehoiada; and he fell upon him that he died.',
#  'of jehoiada, saying, go, fall upon him.  2:30 and',
#  'he hath said, and fall upon him, and bury him;',
#  'lord shall return his blood upon his own head, who',
#  'his own head, who fell upon two men more righteous',
#  ...]

# %% [markdown]
# The nltk package has the full text of several other classic books. You can see what they are called by running the command in the cell below:

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# ## Your turn!
#
# Here are a some more things you can try. In each case, I have given you a little bit of starter code to get you going, but the cells will not run without some additional code from you.

# %% [markdown]
# ## Challenge 1: build your own concordance
#
# Pick a different book and a different word, or pair of words. Copy and paste from the code above to write some Python code that searches the book of your choice for the word or pair of words of your choice. Put this code in the cell below. By the way, some of the texts use the characters "\r" for "carriage return" instead of "\n" for "newline". You can remove these the same way that you remove the "\n" characters.

# %%
# add your code to search for a word or pair of words in a different book here

emma = nltk.corpus.gutenberg.raw('austen-emma.txt')
# gutenberg er samlingen af tekster
# raw bruges til at hente den rå tekst af en fil - du får den som en lang ustruktureret streng

# make all characters lowercase
emma = emma.lower()

# remove the "\n" characters, which indicate line breaks in the text (newlines)
emma = emma.replace('\n', ' ')

# split up the text into a long list of individual words
emma = emma.split(' ')

# %% [markdown]
# ## Challenge 2: compare lengths of books
#
# We can use the command `len` to find how many items there are in a list. E.g., to find the number of words in the list called `bible`, above, we can write: `len(bible)`.
#
# Use the starter code below to find out which book in the books included in `nltk` has the most words.

# %%
# solution 1: print all the titles and numbers of words
# starter code:

books = nltk.corpus.gutenberg.fileids() #file ids returns a list over every text file available in the gutenberg-korpuset

for title in books:
    book = nltk.corpus.gutenberg.raw(title)
     # make all characters lowercase
    book = book.lower()

# remove the "\n" characters, which indicate line breaks in the text (newlines)
    book = book.replace('\n', ' ')

# split up the text into a long list of individual words
    book = book.split(' ') 

    words = len(book)
    print(f'The book {title} has {words} words')
# Out:
# The book austen-emma.txt has 164457 words
# The book austen-persuasion.txt has 86270 words
# The book austen-sense.txt has 123514 words
# The book bible-kjv.txt has 848001 words
# The book blake-poems.txt has 8886 words
# The book bryant-stories.txt has 49404 words
# The book burgess-busterbrown.txt has 16305 words
# The book carroll-alice.txt has 28387 words
# The book chesterton-ball.txt has 86481 words
# The book chesterton-brown.txt has 80382 words
# The book chesterton-thursday.txt has 59297 words
# The book edgeworth-parents.txt has 177685 words
# The book melville-moby_dick.txt has 221023 words
# The book milton-paradise.txt has 91832 words
# The book shakespeare-caesar.txt has 23339 words
# The book shakespeare-hamlet.txt has 33477 words
# The book shakespeare-macbeth.txt has 20164 words
# The book whitman-leaves.txt has 138730 words

# %%
# more advanced, for those with some Python experience, or those who want to google around..
# solution 2: make a list of titles and a list of wordcounts, zip them together, then sort them based on wordcount
# starter code:

books = nltk.corpus.gutenberg.fileids()

titles = []
numwords = []
for title in books:
    book = nltk.corpus.gutenberg.raw(title)
    book = book.lower()
    book = book.replace('\n', ' ')
    book = book.split(' ')
    words = len(book) # jeg tager længden af bogen, dvs. antal ord 
    numwords.append(len(book)) #dem smider jeg ind i min liste numwords, der skal indeholde antal ord
    titles.append(title) #her tilføjer jeg titlen på bogen i min liste titles

wordcount = zip(titles, numwords) # kombinerer de to seperate lister til en enkelt liste af par, 
# der inderholder bogtitel og tilhørende antal ord

sorted_wordcount = sorted(wordcount, reverse = True, key = lambda x: x[1])
# sorted() sorterer, wordcount er listen den skal sortere, reverse = true angiver at den skal starte i omvendt rækkefølge
# key=lambda er en nøglefunktion, der fortæller sorted() at den skal sortere baseret på den anden værdi
# [1] i hver tuple. x repræsenterer hver tuple, og [1] er derfor antallet af ord (den anden værdi i tuplen) 


print (f'{sorted_wordcount [0]} words')
# f' bruges til at lave en sammenhængende streng
# Out:
# ('bible-kjv.txt', 848001) words

# %% [markdown]
# ## Challenge 3: what are the most frequent words?
#
# `nltk` has a built-in function called `FreqDist` which counts up how many times each word in a text occurs. So, if you have a list called `words` which contains all the words in a book, you can find the frequencies of all of them by writing `freq = nltk.FreqDist(words)`. You can then get the e.g. ten most common words by writing `freq.most_common(10)`. What are the ten most common words in Jane Austen's "Emma"? What about Herman Melville's "Moby Dick"?

# %%
# starter code:

book_one = nltk.corpus.gutenberg.raw('austen-emma.txt')
words_one = book_one.lower()
# remove the "\n" characters, which indicate line breaks in the text (newlines)
words_one = book_one.replace('\n', ' ')
# split up the text into a long list of individual words
words_one = book_one.split(' ') 

freq = nltk.FreqDist(words_one) #angiver at det er fra words one den skal tage værdierne 
freq.most_common(10) # fra words one skal den tage de 10 mest forekommende ord
# Out:
# [('to', 4475),
#  ('the', 4380),
#  ('', 3704),
#  ('of', 3647),
#  ('and', 3357),
#  ('a', 2707),
#  ('I', 2151),
#  ('was', 2063),
#  ('not', 1808),
#  ('in', 1791)]

# %%
book_two = nltk.corpus.gutenberg.raw('shakespeare-macbeth.txt')
words_two = book_two.lower()
words_two = book_two.replace('\n', ' ')
words_two = book_two.split(' ')

freq = nltk.FreqDist(words_two)
freq.most_common(10)
# Out:
# [('', 1076),
#  ('the', 522),
#  ('and', 365),
#  ('of', 311),
#  ('to', 307),
#  ('I', 250),
#  ('a', 211),
#  ('my', 166),
#  ('in', 165),
#  ('is', 155)]

# %% [markdown]
# ## Challenge 4: Remove stopwords
#
# Often, the most frequent words are not the most interesting ones. Words like "a" and "the" are so common in English, that they don't really tell us much about the text. That is why we often remove "stopwords", that is, a list of the most common words in English, before e.g. counting frequencies. There are several of these lists available, in [English]((https://gist.github.com/sebleier/554280)) as well as other languages, such as [Danish](https://gist.github.com/berteltorp/0cf8a0c7afea7f25ed754f24cfc2467b). Below is some starter code to remove stopwords. Use these snippets to see what the most common words in Emma and Moby Dick are after removing these most common words.
#
# Hint: In Moby Dick, you will also have to remove the string `\r`, in addition to removing `\n`.

# %%
# list of stopwords

stopwords = ["", "i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# %%
# starter code:

freqdist = []
book = nltk.corpus.gutenberg.raw('austen-emma.txt')
words = book.lower()
words = book.replace('\n', ' ')
words = book.split(' ')


# code to remove stopwords.
words = [word for word in words if word not in stopwords]

freq_one = nltk.FreqDist(words)

freqdist.append(freq_one.most_common(10))
freqdist
# Out:
# [[('I', 2151),
#   ('Mr.', 936),
#   ('could', 682),
#   ('would', 676),
#   ('Mrs.', 575),
#   ('Miss', 491),
#   ('must', 472),
#   ('much', 374),
#   ('said', 354),
#   ('every', 349)]]
