# %%
# to scrape data from wikipedia, we need install the package called lxml
# we can do that here from our notebook or, if we think we will use it often, we could modify our "install_packages"
# shell script to install it automatically each time we start a job in UCloud
# %pip install lxml

# import pandas so we can put data in a nice dataframe
# we'll abbreviate pandas as pd, because that's what everybody does
import pandas as pd
# Out:
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (5.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Scraping data from the web
# Using `pandas.read_html`, we can read data from websites where data is presented in a table-like format. Wikipedia has lots of these, and is a great source for data to play with. Below, we'll look at data from the [List of Sesame Street Muppets](https://en.wikipedia.org/wiki/List_of_Sesame_Street_Muppets)

# %%
# scrape table data from websites

rawdata = pd.read_html("https://en.wikipedia.org/wiki/List_of_Sesame_Street_Muppets")
# read_html leder efter noget der ligner en tabel af data, og indlæser det 
df = rawdata[1]
df
# Out:
#                   Character  \
# 0              Abby Cadabby
# 1       Alice Snuffleupagus
# 2           Alistair Cookie
# 3       The Amazing Mumford
# 4          Anything Muppets
# ..                      ...
# 114           Telly Monster
# 115         The Twiddlebugs
# 116  The Two-Headed Monster
# 117                     Wes
# 118                     Zoe
#
#                                 Actor/Muppet performer  \
# 0                           Leslie Carrara-Rudolph[13]
# 1                                      Judy Sladky[15]
# 2                                         Frank Oz[17]
# 3                   Jerry Nelson,[20] John Kennedy[21]
# 4                                          Various[22]
# ..                                                 ...
# 114  Bob Payne (1979), Brian Muehl (1979–1984),[126...
# 115  Jim Henson, Frank Oz, Jerry Nelson, Richard Hu...
# 116  Left Head: Jerry Nelson[40] Right Head: Richar...
# 117                                Bradley Freeman Jr.
# 118  Fran Brill (1993–2015),[140] Jennifer Barnhart...
#
#                                            Description  \
# 0    A 4-year-old fairy-in-training with tiny wings...
# 1    The baby sister of Aloysius Snuffleupagus ("Sn...
# 2    Played by Cookie Monster, he is a parody of Br...
# 3    A "W.C. Fields-esque" magician whose magic tri...
# 4    Writer Christopher Finch called Anything Muppe...
# ..                                                 ...
# 114  According to Sesame Workshop, "Telly Monster i...
# 115  A family of fuzzy insects (Thomas, Tessie and ...
# 116  A purple monster with two heads, who generally...
# 117  A young Muppet boy. His first appearances incl...
# 118  [86] An orange 3-year-old Muppet who loves to ...
#
#                                             Unnamed: 3
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    Writer Christopher Finch called Anything Muppe...
# ..                                                 ...
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
#
# [119 rows x 4 columns]

# %%
list(df)
# Out:
# ['Character', 'Actor/Muppet performer', 'Description', 'Unnamed: 3']

# %% [markdown]
# ## Removing an unwanted column
# Below are several ways to get rid of the final column (there are more ways to do this!) If you find the "axis = 1" part in the first method confusing, well, I do too, and [we are not alone](https://stackoverflow.com/questions/22149584/what-does-axis-in-pandas-mean)! My advice for now is to just accept it and move on. Probably the easiest method is to use `pop` (method 3)

# %%
# method 1
df = df.drop(['Unnamed: 3'], axis = 1)
df
# Out:
#                   Character  \
# 0              Abby Cadabby
# 1       Alice Snuffleupagus
# 2           Alistair Cookie
# 3       The Amazing Mumford
# 4          Anything Muppets
# ..                      ...
# 114           Telly Monster
# 115         The Twiddlebugs
# 116  The Two-Headed Monster
# 117                     Wes
# 118                     Zoe
#
#                                 Actor/Muppet performer  \
# 0                           Leslie Carrara-Rudolph[13]
# 1                                      Judy Sladky[15]
# 2                                         Frank Oz[17]
# 3                   Jerry Nelson,[20] John Kennedy[21]
# 4                                          Various[22]
# ..                                                 ...
# 114  Bob Payne (1979), Brian Muehl (1979–1984),[126...
# 115  Jim Henson, Frank Oz, Jerry Nelson, Richard Hu...
# 116  Left Head: Jerry Nelson[40] Right Head: Richar...
# 117                                Bradley Freeman Jr.
# 118  Fran Brill (1993–2015),[140] Jennifer Barnhart...
#
#                                            Description
# 0    A 4-year-old fairy-in-training with tiny wings...
# 1    The baby sister of Aloysius Snuffleupagus ("Sn...
# 2    Played by Cookie Monster, he is a parody of Br...
# 3    A "W.C. Fields-esque" magician whose magic tri...
# 4    Writer Christopher Finch called Anything Muppe...
# ..                                                 ...
# 114  According to Sesame Workshop, "Telly Monster i...
# 115  A family of fuzzy insects (Thomas, Tessie and ...
# 116  A purple monster with two heads, who generally...
# 117  A young Muppet boy. His first appearances incl...
# 118  [86] An orange 3-year-old Muppet who loves to ...
#
# [119 rows x 3 columns]

# %%
# method 2
df = df.loc[:,list(df)[0:3]] 
df
# Out:
#                   Character  \
# 0              Abby Cadabby
# 1       Alice Snuffleupagus
# 2           Alistair Cookie
# 3       The Amazing Mumford
# 4          Anything Muppets
# ..                      ...
# 114           Telly Monster
# 115         The Twiddlebugs
# 116  The Two-Headed Monster
# 117                     Wes
# 118                     Zoe
#
#                                 Actor/Muppet performer  \
# 0                           Leslie Carrara-Rudolph[13]
# 1                                      Judy Sladky[15]
# 2                                         Frank Oz[17]
# 3                   Jerry Nelson,[20] John Kennedy[21]
# 4                                          Various[22]
# ..                                                 ...
# 114  Bob Payne (1979), Brian Muehl (1979–1984),[126...
# 115  Jim Henson, Frank Oz, Jerry Nelson, Richard Hu...
# 116  Left Head: Jerry Nelson[40] Right Head: Richar...
# 117                                Bradley Freeman Jr.
# 118  Fran Brill (1993–2015),[140] Jennifer Barnhart...
#
#                                            Description
# 0    A 4-year-old fairy-in-training with tiny wings...
# 1    The baby sister of Aloysius Snuffleupagus ("Sn...
# 2    Played by Cookie Monster, he is a parody of Br...
# 3    A "W.C. Fields-esque" magician whose magic tri...
# 4    Writer Christopher Finch called Anything Muppe...
# ..                                                 ...
# 114  According to Sesame Workshop, "Telly Monster i...
# 115  A family of fuzzy insects (Thomas, Tessie and ...
# 116  A purple monster with two heads, who generally...
# 117  A young Muppet boy. His first appearances incl...
# 118  [86] An orange 3-year-old Muppet who loves to ...
#
# [119 rows x 3 columns]

# %%
# method 3
# df.pop('Unnamed: 3')
# df

# %%
# take a column from a dataframe and assign it to a list variable
a_list = list(df['Character'])
a_list
type(a_list)
# Out:
# list

# %%
# find the first four items in the list
a_list[0:4]
# Out:
# ['Abby Cadabby',
#  'Alice Snuffleupagus',
#  'Alistair Cookie',
#  'The Amazing Mumford']

# %%
# find the last three items in the list
a_list[-3:]
# Out:
# ['The Two-Headed Monster', 'Wes', 'Zoe']

# %%
# find items in the middle of the list
a_list[7:11]
# Out:
# ['Arlene Frantic',
#  'Baby Bear',
#  'Barkley',
#  'Beautiful Day Monster[broken anchor]']

# %%
# select the first 20 items from a list
b = a_list[0:20]

# %%
# remove the last item in a list
b.pop()
# Out:
# 'Buster'

# %%
# inpsect the list to make sure the last item was removed
b
# Out:
# ['Abby Cadabby',
#  'Alice Snuffleupagus',
#  'Alistair Cookie',
#  'The Amazing Mumford',
#  'Anything Muppets',
#  'AM Monsters',
#  'Aristotle',
#  'Arlene Frantic',
#  'Baby Bear',
#  'Barkley',
#  'Beautiful Day Monster[broken anchor]',
#  'Bennett Snerf',
#  'Benny',
#  'Bert',
#  'Betty Lou',
#  'Biff',
#  'Big Bird',
#  'Bip Bippadotta',
#  'Bruno']

# %%
# remove a specific item from the list
b.pop(7)
# Out:
# 'Arlene Frantic'

# %%
# stick a Kermit on the end of the list
b.append('Kermit')

# %%
# inspect the list to make sure Kermit was added
b
# Out:
# ['Abby Cadabby',
#  'Alice Snuffleupagus',
#  'Alistair Cookie',
#  'The Amazing Mumford',
#  'Anything Muppets',
#  'AM Monsters',
#  'Aristotle',
#  'Baby Bear',
#  'Barkley',
#  'Beautiful Day Monster[broken anchor]',
#  'Bennett Snerf',
#  'Benny',
#  'Bert',
#  'Betty Lou',
#  'Biff',
#  'Big Bird',
#  'Bip Bippadotta',
#  'Bruno',
#  'Kermit']

# %%
# insert an item into a list at a particular position
b.insert(5, 'Kermit')
b
# Out:
# ['Abby Cadabby',
#  'Alice Snuffleupagus',
#  'Alistair Cookie',
#  'The Amazing Mumford',
#  'Anything Muppets',
#  'Kermit',
#  'AM Monsters',
#  'Aristotle',
#  'Baby Bear',
#  'Barkley',
#  'Beautiful Day Monster[broken anchor]',
#  'Bennett Snerf',
#  'Benny',
#  'Bert',
#  'Betty Lou',
#  'Biff',
#  'Big Bird',
#  'Bip Bippadotta',
#  'Bruno',
#  'Kermit']

# %%
# replace an item in a list
b[5] = 'Fozzy' #vi skifter plads 5 ud 'kermit, med fozzy
b
# Out:
# ['Abby Cadabby',
#  'Alice Snuffleupagus',
#  'Alistair Cookie',
#  'The Amazing Mumford',
#  'Anything Muppets',
#  'Fozzy',
#  'AM Monsters',
#  'Aristotle',
#  'Baby Bear',
#  'Barkley',
#  'Beautiful Day Monster[broken anchor]',
#  'Bennett Snerf',
#  'Benny',
#  'Bert',
#  'Betty Lou',
#  'Biff',
#  'Big Bird',
#  'Bip Bippadotta',
#  'Bruno',
#  'Kermit']

# %%
# make a new list which adds "is a cute monster" to each item in the list

# Mindst favorit, besværlig - med to loops
string = 'is a cute monster'
new_list = [] 
c = (x + string for x in a_list)
for muppet in c:
    new_list.append(muppet)
new_list
# Out:
# ['Abby Cadabbyis a cute monster',
#  'Alice Snuffleupagusis a cute monster',
#  'Alistair Cookieis a cute monster',
#  'The Amazing Mumfordis a cute monster',
#  'Anything Muppetsis a cute monster',
#  'AM Monstersis a cute monster',
#  'Aristotleis a cute monster',
#  'Arlene Franticis a cute monster',
#  'Baby Bearis a cute monster',
#  'Barkleyis a cute monster',
#  'Beautiful Day Monster[broken anchor]is a cute monster',
#  'Bennett Snerfis a cute monster',
#  'Bennyis a cute monster',
#  'Bertis a cute monster',
#  'Betty Louis a cute monster',
#  'Biffis a cute monster',
#  'Big Birdis a cute monster',
#  'Bip Bippadottais a cute monster',
#  'Brunois a cute monster',
#  'Busteris a cute monster',
#  'Captain Vegetableis a cute monster',
#  'Clementineis a cute monster',
#  'Colambois a cute monster',
#  'Cookie Monsteris a cute monster',
#  'Count von Countis a cute monster',
#  'Countess Dahling von Dahlingis a cute monster',
#  'Curly Bearis a cute monster',
#  'Deenais a cute monster',
#  'Dexteris a cute monster',
#  'Dingersis a cute monster',
#  'Don Musicis a cute monster',
#  'Donald/Ronald Grumpis a cute monster',
#  'Dr. Feelis a cute monster',
#  'Dr. Nobel Priceis a cute monster',
#  'Elizabethis a cute monster',
#  'Elmois a cute monster',
#  'Elijahis a cute monster',
#  'Ernieis a cute monster',
#  'Farleyis a cute monster',
#  'Fatimais a cute monster',
#  'Ferlinghetti Donizettiis a cute monster',
#  'Flo Bearis a cute monster',
#  'Forgetful Jonesis a cute monster',
#  'Frazzleis a cute monster',
#  'Fredis a cute monster',
#  'Gabrielleis a cute monster',
#  'Gladys the Cowis a cute monster',
#  'Granny Birdis a cute monster',
#  'Mrs. Grouchis a cute monster',
#  'Gongeris a cute monster',
#  'Granny Fanny Nestlerodeis a cute monster',
#  'Groveris a cute monster',
#  'Grundgettais a cute monster',
#  'Gulliveris a cute monster',
#  'Guy Smileyis a cute monster',
#  'Harvey Kneeslapperis a cute monster',
#  'Herbert Birdsfootis a cute monster',
#  'Herry Monsteris a cute monster',
#  'Honkersis a cute monster',
#  'Hootsis a cute monster',
#  'Horatiois a cute monster',
#  'Humphreyis a cute monster',
#  'Ingridis a cute monster',
#  'Jamie Foxis a cute monster',
#  'Ji-Youngis a cute monster',
#  'Juliais a cute monster',
#  'Kermit[101]is a cute monster',
#  'Kingston Livingston IIIis a cute monster',
#  'Leftyis a cute monster',
#  'Leois a cute monster',
#  'Little Birdis a cute monster',
#  'Little Chrissyis a cute monster',
#  'Little Jerryis a cute monster',
#  'Little Murray Sparklesis a cute monster',
#  'Lizis a cute monster',
#  'Louieis a cute monster',
#  'Mama Bearis a cute monster',
#  'The Martians[110]is a cute monster',
#  'Merry Monsteris a cute monster',
#  'Meryl Sheepis a cute monster',
#  'Montyis a cute monster',
#  'Mr. Johnsonis a cute monster',
#  'Murray Monsteris a cute monster',
#  'Natashais a cute monster',
#  'Oscar the Grouchis a cute monster',
#  'Ovejita (2008)is a cute monster',
#  'Papa Bearis a cute monster',
#  'Placido Flamingois a cute monster',
#  'Poco Locois a cute monster',
#  'Prairie Dawnis a cute monster',
#  'Prince Charmingis a cute monster',
#  'Professor Hastingsis a cute monster',
#  'Rodeo Rosieis a cute monster',
#  'Roosevelt Franklinis a cute monster',
#  "Roosevelt Franklin's Motheris a cute monster",
#  'Rositais a cute monster',
#  'Roxie Marieis a cute monster',
#  'Rubyis a cute monster',
#  'Rudyis a cute monster',
#  'SAMis a cute monster',
#  'Segi (2010)is a cute monster',
#  'Sherlock Hemlockis a cute monster',
#  'Sherry Netherlandis a cute monster',
#  'Simon Soundmanis a cute monster',
#  'Slimeyis a cute monster',
#  'Smartie (2017)is a cute monster',
#  'Mr. Snuffleupagus ("Snuffy")is a cute monster',
#  'Sonny Friendlyis a cute monster',
#  'The Squirellesis a cute monster',
#  'The Oinker Sisters[134]is a cute monster',
#  'Stinkyis a cute monster',
#  'Sullyis a cute monster',
#  'Tangois a cute monster',
#  'Tamiris a cute monster',
#  'Telly Monsteris a cute monster',
#  'The Twiddlebugsis a cute monster',
#  'The Two-Headed Monsteris a cute monster',
#  'Wesis a cute monster',
#  'Zoeis a cute monster']

# %%
d = [x + ' is a cute monster' for x in a_list] # Samme som før, men mere komprimeret version

d
# Out:
# ['Abby Cadabby is a cute monster',
#  'Alice Snuffleupagus is a cute monster',
#  'Alistair Cookie is a cute monster',
#  'The Amazing Mumford is a cute monster',
#  'Anything Muppets is a cute monster',
#  'AM Monsters is a cute monster',
#  'Aristotle is a cute monster',
#  'Arlene Frantic is a cute monster',
#  'Baby Bear is a cute monster',
#  'Barkley is a cute monster',
#  'Beautiful Day Monster[broken anchor] is a cute monster',
#  'Bennett Snerf is a cute monster',
#  'Benny is a cute monster',
#  'Bert is a cute monster',
#  'Betty Lou is a cute monster',
#  'Biff is a cute monster',
#  'Big Bird is a cute monster',
#  'Bip Bippadotta is a cute monster',
#  'Bruno is a cute monster',
#  'Buster is a cute monster',
#  'Captain Vegetable is a cute monster',
#  'Clementine is a cute monster',
#  'Colambo is a cute monster',
#  'Cookie Monster is a cute monster',
#  'Count von Count is a cute monster',
#  'Countess Dahling von Dahling is a cute monster',
#  'Curly Bear is a cute monster',
#  'Deena is a cute monster',
#  'Dexter is a cute monster',
#  'Dingers is a cute monster',
#  'Don Music is a cute monster',
#  'Donald/Ronald Grump is a cute monster',
#  'Dr. Feel is a cute monster',
#  'Dr. Nobel Price is a cute monster',
#  'Elizabeth is a cute monster',
#  'Elmo is a cute monster',
#  'Elijah is a cute monster',
#  'Ernie is a cute monster',
#  'Farley is a cute monster',
#  'Fatima is a cute monster',
#  'Ferlinghetti Donizetti is a cute monster',
#  'Flo Bear is a cute monster',
#  'Forgetful Jones is a cute monster',
#  'Frazzle is a cute monster',
#  'Fred is a cute monster',
#  'Gabrielle is a cute monster',
#  'Gladys the Cow is a cute monster',
#  'Granny Bird is a cute monster',
#  'Mrs. Grouch is a cute monster',
#  'Gonger is a cute monster',
#  'Granny Fanny Nestlerode is a cute monster',
#  'Grover is a cute monster',
#  'Grundgetta is a cute monster',
#  'Gulliver is a cute monster',
#  'Guy Smiley is a cute monster',
#  'Harvey Kneeslapper is a cute monster',
#  'Herbert Birdsfoot is a cute monster',
#  'Herry Monster is a cute monster',
#  'Honkers is a cute monster',
#  'Hoots is a cute monster',
#  'Horatio is a cute monster',
#  'Humphrey is a cute monster',
#  'Ingrid is a cute monster',
#  'Jamie Fox is a cute monster',
#  'Ji-Young is a cute monster',
#  'Julia is a cute monster',
#  'Kermit[101] is a cute monster',
#  'Kingston Livingston III is a cute monster',
#  'Lefty is a cute monster',
#  'Leo is a cute monster',
#  'Little Bird is a cute monster',
#  'Little Chrissy is a cute monster',
#  'Little Jerry is a cute monster',
#  'Little Murray Sparkles is a cute monster',
#  'Liz is a cute monster',
#  'Louie is a cute monster',
#  'Mama Bear is a cute monster',
#  'The Martians[110] is a cute monster',
#  'Merry Monster is a cute monster',
#  'Meryl Sheep is a cute monster',
#  'Monty is a cute monster',
#  'Mr. Johnson is a cute monster',
#  'Murray Monster is a cute monster',
#  'Natasha is a cute monster',
#  'Oscar the Grouch is a cute monster',
#  'Ovejita (2008) is a cute monster',
#  'Papa Bear is a cute monster',
#  'Placido Flamingo is a cute monster',
#  'Poco Loco is a cute monster',
#  'Prairie Dawn is a cute monster',
#  'Prince Charming is a cute monster',
#  'Professor Hastings is a cute monster',
#  'Rodeo Rosie is a cute monster',
#  'Roosevelt Franklin is a cute monster',
#  "Roosevelt Franklin's Mother is a cute monster",
#  'Rosita is a cute monster',
#  'Roxie Marie is a cute monster',
#  'Ruby is a cute monster',
#  'Rudy is a cute monster',
#  'SAM is a cute monster',
#  'Segi (2010) is a cute monster',
#  'Sherlock Hemlock is a cute monster',
#  'Sherry Netherland is a cute monster',
#  'Simon Soundman is a cute monster',
#  'Slimey is a cute monster',
#  'Smartie (2017) is a cute monster',
#  'Mr. Snuffleupagus ("Snuffy") is a cute monster',
#  'Sonny Friendly is a cute monster',
#  'The Squirelles is a cute monster',
#  'The Oinker Sisters[134] is a cute monster',
#  'Stinky is a cute monster',
#  'Sully is a cute monster',
#  'Tango is a cute monster',
#  'Tamir is a cute monster',
#  'Telly Monster is a cute monster',
#  'The Twiddlebugs is a cute monster',
#  'The Two-Headed Monster is a cute monster',
#  'Wes is a cute monster',
#  'Zoe is a cute monster']

# %%
another_new_list = list() # Klar favorit 
for item in a_list: 
    another_new_list.append(item + ' is a cute monster')

another_new_list
# Out:
# ['Abby Cadabby is a cute monster',
#  'Alice Snuffleupagus is a cute monster',
#  'Alistair Cookie is a cute monster',
#  'The Amazing Mumford is a cute monster',
#  'Anything Muppets is a cute monster',
#  'AM Monsters is a cute monster',
#  'Aristotle is a cute monster',
#  'Arlene Frantic is a cute monster',
#  'Baby Bear is a cute monster',
#  'Barkley is a cute monster',
#  'Beautiful Day Monster[broken anchor] is a cute monster',
#  'Bennett Snerf is a cute monster',
#  'Benny is a cute monster',
#  'Bert is a cute monster',
#  'Betty Lou is a cute monster',
#  'Biff is a cute monster',
#  'Big Bird is a cute monster',
#  'Bip Bippadotta is a cute monster',
#  'Bruno is a cute monster',
#  'Buster is a cute monster',
#  'Captain Vegetable is a cute monster',
#  'Clementine is a cute monster',
#  'Colambo is a cute monster',
#  'Cookie Monster is a cute monster',
#  'Count von Count is a cute monster',
#  'Countess Dahling von Dahling is a cute monster',
#  'Curly Bear is a cute monster',
#  'Deena is a cute monster',
#  'Dexter is a cute monster',
#  'Dingers is a cute monster',
#  'Don Music is a cute monster',
#  'Donald/Ronald Grump is a cute monster',
#  'Dr. Feel is a cute monster',
#  'Dr. Nobel Price is a cute monster',
#  'Elizabeth is a cute monster',
#  'Elmo is a cute monster',
#  'Elijah is a cute monster',
#  'Ernie is a cute monster',
#  'Farley is a cute monster',
#  'Fatima is a cute monster',
#  'Ferlinghetti Donizetti is a cute monster',
#  'Flo Bear is a cute monster',
#  'Forgetful Jones is a cute monster',
#  'Frazzle is a cute monster',
#  'Fred is a cute monster',
#  'Gabrielle is a cute monster',
#  'Gladys the Cow is a cute monster',
#  'Granny Bird is a cute monster',
#  'Mrs. Grouch is a cute monster',
#  'Gonger is a cute monster',
#  'Granny Fanny Nestlerode is a cute monster',
#  'Grover is a cute monster',
#  'Grundgetta is a cute monster',
#  'Gulliver is a cute monster',
#  'Guy Smiley is a cute monster',
#  'Harvey Kneeslapper is a cute monster',
#  'Herbert Birdsfoot is a cute monster',
#  'Herry Monster is a cute monster',
#  'Honkers is a cute monster',
#  'Hoots is a cute monster',
#  'Horatio is a cute monster',
#  'Humphrey is a cute monster',
#  'Ingrid is a cute monster',
#  'Jamie Fox is a cute monster',
#  'Ji-Young is a cute monster',
#  'Julia is a cute monster',
#  'Kermit[101] is a cute monster',
#  'Kingston Livingston III is a cute monster',
#  'Lefty is a cute monster',
#  'Leo is a cute monster',
#  'Little Bird is a cute monster',
#  'Little Chrissy is a cute monster',
#  'Little Jerry is a cute monster',
#  'Little Murray Sparkles is a cute monster',
#  'Liz is a cute monster',
#  'Louie is a cute monster',
#  'Mama Bear is a cute monster',
#  'The Martians[110] is a cute monster',
#  'Merry Monster is a cute monster',
#  'Meryl Sheep is a cute monster',
#  'Monty is a cute monster',
#  'Mr. Johnson is a cute monster',
#  'Murray Monster is a cute monster',
#  'Natasha is a cute monster',
#  'Oscar the Grouch is a cute monster',
#  'Ovejita (2008) is a cute monster',
#  'Papa Bear is a cute monster',
#  'Placido Flamingo is a cute monster',
#  'Poco Loco is a cute monster',
#  'Prairie Dawn is a cute monster',
#  'Prince Charming is a cute monster',
#  'Professor Hastings is a cute monster',
#  'Rodeo Rosie is a cute monster',
#  'Roosevelt Franklin is a cute monster',
#  "Roosevelt Franklin's Mother is a cute monster",
#  'Rosita is a cute monster',
#  'Roxie Marie is a cute monster',
#  'Ruby is a cute monster',
#  'Rudy is a cute monster',
#  'SAM is a cute monster',
#  'Segi (2010) is a cute monster',
#  'Sherlock Hemlock is a cute monster',
#  'Sherry Netherland is a cute monster',
#  'Simon Soundman is a cute monster',
#  'Slimey is a cute monster',
#  'Smartie (2017) is a cute monster',
#  'Mr. Snuffleupagus ("Snuffy") is a cute monster',
#  'Sonny Friendly is a cute monster',
#  'The Squirelles is a cute monster',
#  'The Oinker Sisters[134] is a cute monster',
#  'Stinky is a cute monster',
#  'Sully is a cute monster',
#  'Tango is a cute monster',
#  'Tamir is a cute monster',
#  'Telly Monster is a cute monster',
#  'The Twiddlebugs is a cute monster',
#  'The Two-Headed Monster is a cute monster',
#  'Wes is a cute monster',
#  'Zoe is a cute monster']

# %%
# reset list b to original first 20 items from list a
b = a_list[0:20]
b
# Out:
# ['Abby Cadabby',
#  'Alice Snuffleupagus',
#  'Alistair Cookie',
#  'The Amazing Mumford',
#  'Anything Muppets',
#  'AM Monsters',
#  'Aristotle',
#  'Arlene Frantic',
#  'Baby Bear',
#  'Barkley',
#  'Beautiful Day Monster[broken anchor]',
#  'Bennett Snerf',
#  'Benny',
#  'Bert',
#  'Betty Lou',
#  'Biff',
#  'Big Bird',
#  'Bip Bippadotta',
#  'Bruno',
#  'Buster']

# %%
# make a list of your favorite monsters, 
# and then make a new list which only includes the monsters 
# from list b that are also in your favorites list

fave_monsters = ['Barkley', 'Elmo', 'Big Bird']
new_favemonsters_list = list()
for name in b:
    if name in fave_monsters:
        new_favemonsters_list.append(name)

print(new_favemonsters_list)

# another way to do it 

favs = ['Barkley', 'Elmo', 'Big Bird']
c = [x for x in b if x in favs]
print(c)
# Out:
# ['Barkley', 'Big Bird']
# ['Barkley', 'Big Bird']

# %%
# make a new list which includes the monsters from list b that are not in your favorites list
not_faves = list()
for name in b:
    if name not in fave_monsters:
        not_faves.append(name)
print(not_faves)

# smider bare not in i koden (i løkken) ovenfor
# Out:
# ['Abby Cadabby', 'Alice Snuffleupagus', 'Alistair Cookie', 'The Amazing Mumford', 'Anything Muppets', 'AM Monsters', 'Aristotle', 'Arlene Frantic', 'Baby Bear', 'Beautiful Day Monster[broken anchor]', 'Bennett Snerf', 'Benny', 'Bert', 'Betty Lou', 'Biff', 'Bip Bippadotta', 'Bruno', 'Buster']

# %% [markdown]
# ## More fun with lists

# %%
# add 10 to each number in d
d = [3, 5, 8789, 66]
e = [x + 10 for x in d]
print(e)
# Out:
# [13, 15, 8799, 76]

# %%
# divide each number in d by 2
f = [x / 2 for x in d]
f
# Out:
# [1.5, 2.5, 4394.5, 33.0]

# %% [markdown]
# ## Dataframe manipulation

# %%
# download the student sleep data
df = pd.read_csv("https://raw.githubusercontent.com/ethanweed/ExPsyLing/master/Data/StudentSleep.csv")
df
# Out:
#    Student 1  Student 2  Student 3  Student 4  Student 5  Student 6
# 0         10          8          4         12         10          6
# 1          7          8          3         14          5          6
# 2          7          7          5         11          8          8
# 3          8          9          6         10          9          5
# 4          2          6          6         12          5          6
# 5          5          7          5         14          6          7
# 6          6          7          6         12          9          7

# %%
# find the number of rows and columns in the dataframe
df.shape
# Out:
# (7, 6)

# %%
# make a new dataframe df1 which only includes the first 4 rows of the original dataframe
df1 = df.iloc[0:4]
df1
# Out:
#    Student 1  Student 2  Student 3  Student 4  Student 5  Student 6
# 0         10          8          4         12         10          6
# 1          7          8          3         14          5          6
# 2          7          7          5         11          8          8
# 3          8          9          6         10          9          5

# %%
# make another new dataframe df2 which only includes rows 5 through the end of the original dataframe
df2 = df.iloc[4:df.shape[0]]
df2
# Out:
#    Student 1  Student 2  Student 3  Student 4  Student 5  Student 6
# 4          2          6          6         12          5          6
# 5          5          7          5         14          6          7
# 6          6          7          6         12          9          7

# %%
# make a third dataframe df3 with df2 on top of df1 (hint: use pd.concat)

df3 = pd.concat([df2, df1])
df3
# Out:
#    Student 1  Student 2  Student 3  Student 4  Student 5  Student 6
# 4          2          6          6         12          5          6
# 5          5          7          5         14          6          7
# 6          6          7          6         12          9          7
# 0         10          8          4         12         10          6
# 1          7          8          3         14          5          6
# 2          7          7          5         11          8          8
# 3          8          9          6         10          9          5

# %%
# overwrite df3 with df1 and df2 back in their original order
df3 = df
df3
# Out:
#    Student 1  Student 2  Student 3  Student 4  Student 5  Student 6
# 0         10          8          4         12         10          6
# 1          7          8          3         14          5          6
# 2          7          7          5         11          8          8
# 3          8          9          6         10          9          5
# 4          2          6          6         12          5          6
# 5          5          7          5         14          6          7
# 6          6          7          6         12          9          7

# %%
# make a new column called "average" which is the mean of the other columns for each row
df3['average'] = df3.mean(axis = 1)
df3
# Out:
#    Student 1  Student 2  Student 3  Student 4  Student 5  Student 6   average
# 0         10          8          4         12         10          6  8.333333
# 1          7          8          3         14          5          6  7.166667
# 2          7          7          5         11          8          8  7.666667
# 3          8          9          6         10          9          5  7.833333
# 4          2          6          6         12          5          6  6.166667
# 5          5          7          5         14          6          7  7.333333
# 6          6          7          6         12          9          7  7.833333

# %%
# remove the average column from the dataframe
df3.pop('average')
df3
# Out:
#    Student 1  Student 2  Student 3  Student 4  Student 5  Student 6
# 0         10          8          4         12         10          6
# 1          7          8          3         14          5          6
# 2          7          7          5         11          8          8
# 3          8          9          6         10          9          5
# 4          2          6          6         12          5          6
# 5          5          7          5         14          6          7
# 6          6          7          6         12          9          7

# %%
# make a list of the means of each column in the dataframe
column_means = list(df3.mean())
column_means
# Out:
# [6.428571428571429,
#  7.428571428571429,
#  5.0,
#  12.142857142857142,
#  7.428571428571429,
#  6.428571428571429]

# %%
# make a list of the means of each row in the dataframe
colnames = list(df3)
colnames
# Out:
# ['Student 1', 'Student 2', 'Student 3', 'Student 4', 'Student 5', 'Student 6']

# %%
list(zip(colnames, column_means))
# Out:
# [('Student 1', 6.428571428571429),
#  ('Student 2', 7.428571428571429),
#  ('Student 3', 5.0),
#  ('Student 4', 12.142857142857142),
#  ('Student 5', 7.428571428571429),
#  ('Student 6', 6.428571428571429)]

# %%
student_means = dict(zip(colnames, column_means))
student_means
# Out:
# {'Student 1': 6.428571428571429,
#  'Student 2': 7.428571428571429,
#  'Student 3': 5.0,
#  'Student 4': 12.142857142857142,
#  'Student 5': 7.428571428571429,
#  'Student 6': 6.428571428571429}

# %%
print('Student 4\'s average:', round(student_means['Student 4'], 3))
# Out:
# Student 4's average: 12.143

# %%
# make a dataframe the mean hours of sleep for each student
df_means = pd.DataFrame(zip(colnames, column_means))
df_means.columns = ['Students', 'Sleep Hours']
df_means
# Out:
#     Students  Sleep Hours
# 0  Student 1     6.428571
# 1  Student 2     7.428571
# 2  Student 3     5.000000
# 3  Student 4    12.142857
# 4  Student 5     7.428571
# 5  Student 6     6.428571

# %%
# transpose the dataframe
df_transposed = df3.transpose()
df_transposed
# Out:
#             0   1   2   3   4   5   6
# Student 1  10   7   7   8   2   5   6
# Student 2   8   8   7   9   6   7   7
# Student 3   4   3   5   6   6   5   6
# Student 4  12  14  11  10  12  14  12
# Student 5  10   5   8   9   5   6   9
# Student 6   6   6   8   5   6   7   7

# %%
colnames = list(df_transposed)
colnames
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
# using list comprehension to take each columns name, 
# add 1 to it, make it into a string, put day in front of that, and do it to all 

newcols = ['Day ' + str(x+1) for x in colnames]
newcols
# Out:
# ['Day 1', 'Day 2', 'Day 3', 'Day 4', 'Day 5', 'Day 6', 'Day 7']

# %%
df_transposed.columns = newcols
df_transposed
# Out:
#            Day 1  Day 2  Day 3  Day 4  Day 5  Day 6  Day 7
# Student 1     10      7      7      8      2      5      6
# Student 2      8      8      7      9      6      7      7
# Student 3      4      3      5      6      6      5      6
# Student 4     12     14     11     10     12     14     12
# Student 5     10      5      8      9      5      6      9
# Student 6      6      6      8      5      6      7      7

# %%
df_transposed.index.name = 'student'
df_transposed
# Out:
#            Day 1  Day 2  Day 3  Day 4  Day 5  Day 6  Day 7
# student
# Student 1     10      7      7      8      2      5      6
# Student 2      8      8      7      9      6      7      7
# Student 3      4      3      5      6      6      5      6
# Student 4     12     14     11     10     12     14     12
# Student 5     10      5      8      9      5      6      9
# Student 6      6      6      8      5      6      7      7

# %%
df_transposed.reset_index(inplace = True)
df_transposed
# Out:
#      student  Day 1  Day 2  Day 3  Day 4  Day 5  Day 6  Day 7
# 0  Student 1     10      7      7      8      2      5      6
# 1  Student 2      8      8      7      9      6      7      7
# 2  Student 3      4      3      5      6      6      5      6
# 3  Student 4     12     14     11     10     12     14     12
# 4  Student 5     10      5      8      9      5      6      9
# 5  Student 6      6      6      8      5      6      7      7

# %%
df_long = pd.melt(df_transposed, id_vars = 'student')
df_long
# Out:
#       student variable  value
# 0   Student 1    Day 1     10
# 1   Student 2    Day 1      8
# 2   Student 3    Day 1      4
# 3   Student 4    Day 1     12
# 4   Student 5    Day 1     10
# 5   Student 6    Day 1      6
# 6   Student 1    Day 2      7
# 7   Student 2    Day 2      8
# 8   Student 3    Day 2      3
# 9   Student 4    Day 2     14
# 10  Student 5    Day 2      5
# 11  Student 6    Day 2      6
# 12  Student 1    Day 3      7
# 13  Student 2    Day 3      7
# 14  Student 3    Day 3      5
# 15  Student 4    Day 3     11
# 16  Student 5    Day 3      8
# 17  Student 6    Day 3      8
# 18  Student 1    Day 4      8
# 19  Student 2    Day 4      9
# 20  Student 3    Day 4      6
# 21  Student 4    Day 4     10
# 22  Student 5    Day 4      9
# 23  Student 6    Day 4      5
# 24  Student 1    Day 5      2
# 25  Student 2    Day 5      6
# 26  Student 3    Day 5      6
# 27  Student 4    Day 5     12
# 28  Student 5    Day 5      5
# 29  Student 6    Day 5      6
# 30  Student 1    Day 6      5
# 31  Student 2    Day 6      7
# 32  Student 3    Day 6      5
# 33  Student 4    Day 6     14
# 34  Student 5    Day 6      6
# 35  Student 6    Day 6      7
# 36  Student 1    Day 7      6
# 37  Student 2    Day 7      7
# 38  Student 3    Day 7      6
# 39  Student 4    Day 7     12
# 40  Student 5    Day 7      9
# 41  Student 6    Day 7      7
